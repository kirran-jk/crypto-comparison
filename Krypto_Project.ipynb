# %%
import alpha_api
import pandas as pd
from sqlalchemy import create_engine
import datetime
import requests
from alpha_api import pgAdmin_pw

# %% [markdown]
# ## Retrieve CSV Files

# %%
BTC_filepath = 'Resources/coin_Bitcoin.csv'
ETH_filepath = 'Resources/coin_Ethereum.csv'

# %% [markdown]
# ## Store in Dataframes

# %% [markdown]
# Read csv files, drop unwanted columns, change date format

# %%
ETH_df = pd.read_csv(ETH_filepath)
ETH_df = ETH_df[['Date','Name','Symbol','Open','Close']]
ETH_df['Date'] = pd.to_datetime(ETH_df['Date'])
ETH_df['Date'] = ETH_df['Date'].dt.date
ETH_df.rename(columns = {'Date':'date','Name':'name','Symbol':'symbol','Open':'open','Close':'close'}, inplace=True)
ETH_df.head()
# Out:
#          date      name symbol      open     close
# 0  2015-08-08  Ethereum    ETH  2.793760  0.753325
# 1  2015-08-09  Ethereum    ETH  0.706136  0.701897
# 2  2015-08-10  Ethereum    ETH  0.713989  0.708448
# 3  2015-08-11  Ethereum    ETH  0.708087  1.067860
# 4  2015-08-12  Ethereum    ETH  1.058750  1.217440

# %%
BTC_df = pd.read_csv(BTC_filepath)
BTC_df = BTC_df[['Date','Name','Symbol','Open','Close']]
BTC_df['Date'] = pd.to_datetime(BTC_df['Date'])
BTC_df['Date'] = BTC_df['Date'].dt.date
BTC_df.rename(columns = {'Date':'date','Name':'name','Symbol':'symbol','Open':'open','Close':'close'}, inplace=True)
BTC_df
# Out:
#             date     name symbol          open         close
# 0     2013-04-29  Bitcoin    BTC    134.444000    144.539993
# 1     2013-04-30  Bitcoin    BTC    144.000000    139.000000
# 2     2013-05-01  Bitcoin    BTC    139.000000    116.989998
# 3     2013-05-02  Bitcoin    BTC    116.379997    105.209999
# 4     2013-05-03  Bitcoin    BTC    106.250000     97.750000
# ...          ...      ...    ...           ...           ...
# 2986  2021-07-02  Bitcoin    BTC  33549.600177  33897.048590
# 2987  2021-07-03  Bitcoin    BTC  33854.421362  34668.548402
# 2988  2021-07-04  Bitcoin    BTC  34665.564866  35287.779766
# 2989  2021-07-05  Bitcoin    BTC  35284.344430  33746.002456
# 2990  2021-07-06  Bitcoin    BTC  33723.509655  34235.193451
#
# [2991 rows x 5 columns]

# %%
BTC_df_dates = BTC_df.loc[BTC_df['date'] >= datetime.date(2015,8,8)]
BTC_df_dates
# Out:
#             date     name symbol          open         close
# 831   2015-08-08  Bitcoin    BTC    279.742004    260.997009
# 832   2015-08-09  Bitcoin    BTC    261.115997    265.083008
# 833   2015-08-10  Bitcoin    BTC    265.477997    264.470001
# 834   2015-08-11  Bitcoin    BTC    264.342010    270.385986
# 835   2015-08-12  Bitcoin    BTC    270.597992    266.376007
# ...          ...      ...    ...           ...           ...
# 2986  2021-07-02  Bitcoin    BTC  33549.600177  33897.048590
# 2987  2021-07-03  Bitcoin    BTC  33854.421362  34668.548402
# 2988  2021-07-04  Bitcoin    BTC  34665.564866  35287.779766
# 2989  2021-07-05  Bitcoin    BTC  35284.344430  33746.002456
# 2990  2021-07-06  Bitcoin    BTC  33723.509655  34235.193451
#
# [2160 rows x 5 columns]

# %% [markdown]
# ## Retrieve JSON data

# %%
eth_url = f'https://www.alphavantage.co/query?function=DIGITAL_CURRENCY_DAILY&symbol=ETH&market=USD&apikey={alpha_api}'
btc_url = f'https://www.alphavantage.co/query?function=DIGITAL_CURRENCY_DAILY&symbol=BTC&market=USD&apikey={alpha_api}'

# %%
ETH_response = requests.get(eth_url).json()
ETH_dates = ETH_response['Time Series (Digital Currency Daily)']
ETH_dates
# Out:
# {'2022-08-19': {'1a. open (USD)': '1846.39000000',
#   '1b. open (USD)': '1846.39000000',
#   '2a. high (USD)': '1848.00000000',
#   '2b. high (USD)': '1848.00000000',
#   '3a. low (USD)': '1811.10000000',
#   '3b. low (USD)': '1811.10000000',
#   '4a. close (USD)': '1819.00000000',
#   '4b. close (USD)': '1819.00000000',
#   '5. volume': '52316.17290000',
#   '6. market cap (USD)': '52316.17290000'},
#  '2022-08-18': {'1a. open (USD)': '1834.24000000',
#   '1b. open (USD)': '1834.24000000',
#   '2a. high (USD)': '1882.37000000',
#   '2b. high (USD)': '1882.37000000',
#   '3a. low (USD)': '1821.25000000',
#   '3b. low (USD)': '1821.25000000',
#   '4a. close (USD)': '1846.39000000',
#   '4b. close (USD)': '1846.39000000',
#   '5. volume': '606254.02400000',
#   '6. market cap (USD)': '606254.02400000'},
#  '2022-08-17': {'1a. open (USD)': '1876.67000000',
#   '1b. open (USD)': '1876.67000000',
#   '2a. high (USD)': '1959.43000000',
#   '2b. high (USD)': '1959.43000000',
#   '3a. low (USD)': '1818.74000000',
#   '3b. low (USD)': '1818.74000000',
#   '4a. close (USD)': '1834.25000000',
#   '4b. close (USD)': '1834.25000000',
#   '5. volume': '951824.89750000',
#   '6. market cap (USD)': '951824.89750000'},
#  '2022-08-16': {'1a. open (USD)': '1899.05000000',
#   '1b. open (USD)': '1899.05000000',
#   '2a. high (USD)': '1915.00000000',
#   '2b. high (USD)': '1915.00000000',
#   '3a. low (USD)': '1853.00000000',
#   '3b. low (USD)': '1853.00000000',
#   '4a. close (USD)': '1876.67000000',
#   '4b. close (USD)': '1876.67000000',
#   '5. volume': '622729.14990000',
#   '6. market cap (USD)': '622729.14990000'},
#  '2022-08-15': {'1a. open (USD)': '1935.32000000',
#   '1b. open (USD)': '1935.32000000',
#   '2a. high (USD)': '2012.47000000',
#   '2b. high (USD)': '2012.47000000',
#   '3a. low (USD)': '1872.31000000',
#   '3b. low (USD)': '1872.31000000',
#   '4a. close (USD)': '1899.06000000',
#   '4b. close (USD)': '1899.06000000',
#   '5. volume': '949162.33050000',
#   '6. market cap (USD)': '949162.33050000'},
#  '2022-08-14': {'1a. open (USD)': '1983.55000000',
#   '1b. open (USD)': '1983.55000000',
#   '2a. high (USD)': '2030.00000000',
#   '2b. high (USD)': '2030.00000000',
#   '3a. low (USD)': '1906.00000000',
#   '3b. low (USD)': '1906.00000000',
#   '4a. close (USD)': '1935.31000000',
#   '4b. close (USD)': '1935.31000000',
#   '5. volume': '569583.48520000',
#   '6. market cap (USD)': '569583.48520000'},
#  '2022-08-13': {'1a. open (USD)': '1958.28000000',
#   '1b. open (USD)': '1958.28000000',
#   '2a. high (USD)': '2020.00000000',
#   '2b. high (USD)': '2020.00000000',
#   '3a. low (USD)': '1946.50000000',
#   '3b. low (USD)': '1946.50000000',
#   '4a. close (USD)': '1983.55000000',
#   '4b. close (USD)': '1983.55000000',
#   '5. volume': '695876.02930000',
#   '6. market cap (USD)': '695876.02930000'},
#  '2022-08-12': {'1a. open (USD)': '1880.19000000',
#   '1b. open (USD)': '1880.19000000',
#   '2a. high (USD)': '1964.71000000',
#   '2b. high (USD)': '1964.71000000',
#   '3a. low (USD)': '1853.06000000',
#   '3b. low (USD)': '1853.06000000',
#   '4a. close (USD)': '1958.28000000',
#   '4b. close (USD)': '1958.28000000',
#   '5. volume': '717628.10150000',
#   '6. market cap (USD)': '717628.10150000'},
#  '2022-08-11': {'1a. open (USD)': '1853.58000000',
#   '1b. open (USD)': '1853.58000000',
#   '2a. high (USD)': '1942.00000000',
#   '2b. high (USD)': '1942.00000000',
#   '3a. low (USD)': '1850.32000000',
#   '3b. low (USD)': '1850.32000000',
#   '4a. close (USD)': '1880.19000000',
#   '4b. close (USD)': '1880.19000000',
#   '5. volume': '1105261.90090000',
#   '6. market cap (USD)': '1105261.90090000'},
#  '2022-08-10': {'1a. open (USD)': '1702.76000000',
#   '1b. open (USD)': '1702.76000000',
#   '2a. high (USD)': '1885.00000000',
#   '2b. high (USD)': '1885.00000000',
#   '3a. low (USD)': '1656.78000000',
#   '3b. low (USD)': '1656.78000000',
#   '4a. close (USD)': '1853.57000000',
#   '4b. close (USD)': '1853.57000000',
#   '5. volume': '1317767.51270000',
#   '6. market cap (USD)': '1317767.51270000'},
#  '2022-08-09': {'1a. open (USD)': '1777.05000000',
#   '1b. open (USD)': '1777.05000000',
#   '2a. high (USD)': '1790.83000000',
#   '2b. high (USD)': '1790.83000000',
#   '3a. low (USD)': '1667.93000000',
#   '3b. low (USD)': '1667.93000000',
#   '4a. close (USD)': '1702.76000000',
#   '4b. close (USD)': '1702.76000000',
#   '5. volume': '818171.10190000',
#   '6. market cap (USD)': '818171.10190000'},
#  '2022-08-08': {'1a. open (USD)': '1700.20000000',
#   '1b. open (USD)': '1700.20000000',
#   '2a. high (USD)': '1818.00000000',
#   '2b. high (USD)': '1818.00000000',
#   '3a. low (USD)': '1693.87000000',
#   '3b. low (USD)': '1693.87000000',
#   '4a. close (USD)': '1777.05000000',
#   '4b. close (USD)': '1777.05000000',
#   '5. volume': '781620.54430000',
#   '6. market cap (USD)': '781620.54430000'},
#  '2022-08-07': {'1a. open (USD)': '1690.60000000',
#   '1b. open (USD)': '1690.60000000',
#   '2a. high (USD)': '1729.79000000',
#   '2b. high (USD)': '1729.79000000',
#   '3a. low (USD)': '1668.00000000',
#   '3b. low (USD)': '1668.00000000',
#   '4a. close (USD)': '1700.19000000',
#   '4b. close (USD)': '1700.19000000',
#   '5. volume': '439904.76400000',
#   '6. market cap (USD)': '439904.76400000'},
#  '2022-08-06': {'1a. open (USD)': '1736.81000000',
#   '1b. open (USD)': '1736.81000000',
#   '2a. high (USD)': '1749.93000000',
#   '2b. high (USD)': '1749.93000000',
#   '3a. low (USD)': '1685.26000000',
#   '3b. low (USD)': '1685.26000000',
#   '4a. close (USD)': '1690.60000000',
#   '4b. close (USD)': '1690.60000000',
#   '5. volume': '523314.64440000',
#   '6. market cap (USD)': '523314.64440000'},
#  '2022-08-05': {'1a. open (USD)': '1607.97000000',
#   '1b. open (USD)': '1607.97000000',
#   '2a. high (USD)': '1742.07000000',
#   '2b. high (USD)': '1742.07000000',
#   '3a. low (USD)': '1605.64000000',
#   '3b. low (USD)': '1605.64000000',
#   '4a. close (USD)': '1736.81000000',
#   '4b. close (USD)': '1736.81000000',
#   '5. volume': '1005846.47120000',
#   '6. market cap (USD)': '1005846.47120000'},
#  '2022-08-04': {'1a. open (USD)': '1618.16000000',
#   '1b. open (USD)': '1618.16000000',
#   '2a. high (USD)': '1662.79000000',
#   '2b. high (USD)': '1662.79000000',
#   '3a. low (USD)': '1580.39000000',
#   '3b. low (USD)': '1580.39000000',
#   '4a. close (USD)': '1607.96000000',
#   '4b. close (USD)': '1607.96000000',
#   '5. volume': '735552.18100000',
#   '6. market cap (USD)': '735552.18100000'},
#  '2022-08-03': {'1a. open (USD)': '1630.91000000',
#   '1b. open (USD)': '1630.91000000',
#   '2a. high (USD)': '1685.03000000',
#   '2b. high (USD)': '1685.03000000',
#   '3a. low (USD)': '1589.71000000',
#   '3b. low (USD)': '1589.71000000',
#   '4a. close (USD)': '1618.16000000',
#   '4b. close (USD)': '1618.16000000',
#   '5. volume': '777724.74130000',
#   '6. market cap (USD)': '777724.74130000'},
#  '2022-08-02': {'1a. open (USD)': '1630.28000000',
#   '1b. open (USD)': '1630.28000000',
#   '2a. high (USD)': '1678.00000000',
#   '2b. high (USD)': '1678.00000000',
#   '3a. low (USD)': '1559.28000000',
#   '3b. low (USD)': '1559.28000000',
#   '4a. close (USD)': '1630.91000000',
#   '4b. close (USD)': '1630.91000000',
#   '5. volume': '1081964.51040000',
#   '6. market cap (USD)': '1081964.51040000'},
#  '2022-08-01': {'1a. open (USD)': '1678.12000000',
#   '1b. open (USD)': '1678.12000000',
#   '2a. high (USD)': '1704.68000000',
#   '2b. high (USD)': '1704.68000000',
#   '3a. low (USD)': '1606.12000000',
#   '3b. low (USD)': '1606.12000000',
#   '4a. close (USD)': '1630.28000000',
#   '4b. close (USD)': '1630.28000000',
#   '5. volume': '801566.56480000',
#   '6. market cap (USD)': '801566.56480000'},
#  '2022-07-31': {'1a. open (USD)': '1697.00000000',
#   '1b. open (USD)': '1697.00000000',
#   '2a. high (USD)': '1754.69000000',
#   '2b. high (USD)': '1754.69000000',
#   '3a. low (USD)': '1666.00000000',
#   '3b. low (USD)': '1666.00000000',
#   '4a. close (USD)': '1678.12000000',
#   '4b. close (USD)': '1678.12000000',
#   '5. volume': '696326.80790000',
#   '6. market cap (USD)': '696326.80790000'},
#  '2022-07-30': {'1a. open (USD)': '1721.68000000',
#   '1b. open (USD)': '1721.68000000',
#   '2a. high (USD)': '1744.85000000',
#   '2b. high (USD)': '1744.85000000',
#   '3a. low (USD)': '1673.01000000',
#   '3b. low (USD)': '1673.01000000',
#   '4a. close (USD)': '1697.00000000',
#   '4b. close (USD)': '1697.00000000',
#   '5. volume': '735132.52860000',
#   '6. market cap (USD)': '735132.52860000'},
#  '2022-07-29': {'1a. open (USD)': '1724.52000000',
#   '1b. open (USD)': '1724.52000000',
#   '2a. high (USD)': '1765.99000000',
#   '2b. high (USD)': '1765.99000000',
#   '3a. low (USD)': '1655.02000000',
#   '3b. low (USD)': '1655.02000000',
#   '4a. close (USD)': '1721.68000000',
#   '4b. close (USD)': '1721.68000000',
#   '5. volume': '1205266.57030000',
#   '6. market cap (USD)': '1205266.57030000'},
#  '2022-07-28': {'1a. open (USD)': '1635.74000000',
#   '1b. open (USD)': '1635.74000000',
#   '2a. high (USD)': '1784.79000000',
#   '2b. high (USD)': '1784.79000000',
#   '3a. low (USD)': '1593.27000000',
#   '3b. low (USD)': '1593.27000000',
#   '4a. close (USD)': '1724.52000000',
#   '4b. close (USD)': '1724.52000000',
#   '5. volume': '1578145.07555000',
#   '6. market cap (USD)': '1578145.07555000'},
#  '2022-07-27': {'1a. open (USD)': '1449.12000000',
#   '1b. open (USD)': '1449.12000000',
#   '2a. high (USD)': '1644.44000000',
#   '2b. high (USD)': '1644.44000000',
#   '3a. low (USD)': '1420.83000000',
#   '3b. low (USD)': '1420.83000000',
#   '4a. close (USD)': '1635.74000000',
#   '4b. close (USD)': '1635.74000000',
#   '5. volume': '1513426.04130000',
#   '6. market cap (USD)': '1513426.04130000'},
#  '2022-07-26': {'1a. open (USD)': '1440.79000000',
#   '1b. open (USD)': '1440.79000000',
#   '2a. high (USD)': '1454.11000000',
#   '2b. high (USD)': '1454.11000000',
#   '3a. low (USD)': '1356.17000000',
#   '3b. low (USD)': '1356.17000000',
#   '4a. close (USD)': '1449.12000000',
#   '4b. close (USD)': '1449.12000000',
#   '5. volume': '1199643.74080000',
#   '6. market cap (USD)': '1199643.74080000'},
#  '2022-07-25': {'1a. open (USD)': '1597.70000000',
#   '1b. open (USD)': '1597.70000000',
#   '2a. high (USD)': '1609.55000000',
#   '2b. high (USD)': '1609.55000000',
#   '3a. low (USD)': '1435.58000000',
#   '3b. low (USD)': '1435.58000000',
#   '4a. close (USD)': '1440.79000000',
#   '4b. close (USD)': '1440.79000000',
#   '5. volume': '1418390.98090000',
#   '6. market cap (USD)': '1418390.98090000'},
#  '2022-07-24': {'1a. open (USD)': '1548.66000000',
#   '1b. open (USD)': '1548.66000000',
#   '2a. high (USD)': '1664.34000000',
#   '2b. high (USD)': '1664.34000000',
#   '3a. low (USD)': '1545.67000000',
#   '3b. low (USD)': '1545.67000000',
#   '4a. close (USD)': '1597.70000000',
#   '4b. close (USD)': '1597.70000000',
#   '5. volume': '1009935.89970000',
#   '6. market cap (USD)': '1009935.89970000'},
#  '2022-07-23': {'1a. open (USD)': '1535.27000000',
#   '1b. open (USD)': '1535.27000000',
#   '2a. high (USD)': '1596.51000000',
#   '2b. high (USD)': '1596.51000000',
#   '3a. low (USD)': '1488.00000000',
#   '3b. low (USD)': '1488.00000000',
#   '4a. close (USD)': '1548.67000000',
#   '4b. close (USD)': '1548.67000000',
#   '5. volume': '851284.73390000',
#   '6. market cap (USD)': '851284.73390000'},
#  '2022-07-22': {'1a. open (USD)': '1575.45000000',
#   '1b. open (USD)': '1575.45000000',
#   '2a. high (USD)': '1650.05000000',
#   '2b. high (USD)': '1650.05000000',
#   '3a. low (USD)': '1516.11000000',
#   '3b. low (USD)': '1516.11000000',
#   '4a. close (USD)': '1535.27000000',
#   '4b. close (USD)': '1535.27000000',
#   '5. volume': '1170723.08730000',
#   '6. market cap (USD)': '1170723.08730000'},
#  '2022-07-21': {'1a. open (USD)': '1521.63000000',
#   '1b. open (USD)': '1521.63000000',
#   '2a. high (USD)': '1605.98000000',
#   '2b. high (USD)': '1605.98000000',
#   '3a. low (USD)': '1463.56000000',
#   '3b. low (USD)': '1463.56000000',
#   '4a. close (USD)': '1575.45000000',
#   '4b. close (USD)': '1575.45000000',
#   '5. volume': '1247327.49630000',
#   '6. market cap (USD)': '1247327.49630000'},
#  '2022-07-20': {'1a. open (USD)': '1542.33000000',
#   '1b. open (USD)': '1542.33000000',
#   '2a. high (USD)': '1620.40000000',
#   '2b. high (USD)': '1620.40000000',
#   '3a. low (USD)': '1484.23000000',
#   '3b. low (USD)': '1484.23000000',
#   '4a. close (USD)': '1521.58000000',
#   '4b. close (USD)': '1521.58000000',
#   '5. volume': '1351177.42470000',
#   '6. market cap (USD)': '1351177.42470000'},
#  '2022-07-19': {'1a. open (USD)': '1581.03000000',
#   '1b. open (USD)': '1581.03000000',
#   '2a. high (USD)': '1631.00000000',
#   '2b. high (USD)': '1631.00000000',
#   '3a. low (USD)': '1493.11000000',
#   '3b. low (USD)': '1493.11000000',
#   '4a. close (USD)': '1542.32000000',
#   '4b. close (USD)': '1542.32000000',
#   '5. volume': '1846048.68160000',
#   '6. market cap (USD)': '1846048.68160000'},
#  '2022-07-18': {'1a. open (USD)': '1338.65000000',
#   '1b. open (USD)': '1338.65000000',
#   '2a. high (USD)': '1597.47000000',
#   '2b. high (USD)': '1597.47000000',
#   '3a. low (USD)': '1336.07000000',
#   '3b. low (USD)': '1336.07000000',
#   '4a. close (USD)': '1581.04000000',
#   '4b. close (USD)': '1581.04000000',
#   '5. volume': '2029918.76521000',
#   '6. market cap (USD)': '2029918.76521000'},
#  '2022-07-17': {'1a. open (USD)': '1355.84000000',
#   '1b. open (USD)': '1355.84000000',
#   '2a. high (USD)': '1387.00000000',
#   '2b. high (USD)': '1387.00000000',
#   '3a. low (USD)': '1319.04000000',
#   '3b. low (USD)': '1319.04000000',
#   '4a. close (USD)': '1338.65000000',
#   '4b. close (USD)': '1338.65000000',
#   '5. volume': '1246202.87950000',
#   '6. market cap (USD)': '1246202.87950000'},
#  '2022-07-16': {'1a. open (USD)': '1231.25000000',
#   '1b. open (USD)': '1231.25000000',
#   '2a. high (USD)': '1422.91000000',
#   '2b. high (USD)': '1422.91000000',
#   '3a. low (USD)': '1191.23000000',
#   '3b. low (USD)': '1191.23000000',
#   '4a. close (USD)': '1355.85000000',
#   '4b. close (USD)': '1355.85000000',
#   '5. volume': '1493809.92260000',
#   '6. market cap (USD)': '1493809.92260000'},
#  '2022-07-15': {'1a. open (USD)': '1193.42000000',
#   '1b. open (USD)': '1193.42000000',
#   '2a. high (USD)': '1287.82000000',
#   '2b. high (USD)': '1287.82000000',
#   '3a. low (USD)': '1181.05000000',
#   '3b. low (USD)': '1181.05000000',
#   '4a. close (USD)': '1231.25000000',
#   '4b. close (USD)': '1231.25000000',
#   '5. volume': '1466037.25840000',
#   '6. market cap (USD)': '1466037.25840000'},
#  '2022-07-14': {'1a. open (USD)': '1115.01000000',
#   '1b. open (USD)': '1115.01000000',
#   '2a. high (USD)': '1214.65000000',
#   '2b. high (USD)': '1214.65000000',
#   '3a. low (USD)': '1072.11000000',
#   '3b. low (USD)': '1072.11000000',
#   '4a. close (USD)': '1193.42000000',
#   '4b. close (USD)': '1193.42000000',
#   '5. volume': '1605101.92620000',
#   '6. market cap (USD)': '1605101.92620000'},
#  '2022-07-13': {'1a. open (USD)': '1038.58000000',
#   '1b. open (USD)': '1038.58000000',
#   '2a. high (USD)': '1119.18000000',
#   '2b. high (USD)': '1119.18000000',
#   '3a. low (USD)': '1006.32000000',
#   '3b. low (USD)': '1006.32000000',
#   '4a. close (USD)': '1115.00000000',
#   '4b. close (USD)': '1115.00000000',
#   '5. volume': '2035605.82990000',
#   '6. market cap (USD)': '2035605.82990000'},
#  '2022-07-12': {'1a. open (USD)': '1096.37000000',
#   '1b. open (USD)': '1096.37000000',
#   '2a. high (USD)': '1098.26000000',
#   '2b. high (USD)': '1098.26000000',
#   '3a. low (USD)': '1033.46000000',
#   '3b. low (USD)': '1033.46000000',
#   '4a. close (USD)': '1038.58000000',
#   '4b. close (USD)': '1038.58000000',
#   '5. volume': '1261349.63210000',
#   '6. market cap (USD)': '1261349.63210000'},
#  '2022-07-11': {'1a. open (USD)': '1168.37000000',
#   '1b. open (USD)': '1168.37000000',
#   '2a. high (USD)': '1171.29000000',
#   '2b. high (USD)': '1171.29000000',
#   '3a. low (USD)': '1091.71000000',
#   '3b. low (USD)': '1091.71000000',
#   '4a. close (USD)': '1096.40000000',
#   '4b. close (USD)': '1096.40000000',
#   '5. volume': '1201652.30480000',
#   '6. market cap (USD)': '1201652.30480000'},
#  '2022-07-10': {'1a. open (USD)': '1217.02000000',
#   '1b. open (USD)': '1217.02000000',
#   '2a. high (USD)': '1219.95000000',
#   '2b. high (USD)': '1219.95000000',
#   '3a. low (USD)': '1153.00000000',
#   '3b. low (USD)': '1153.00000000',
#   '4a. close (USD)': '1168.36000000',
#   '4b. close (USD)': '1168.36000000',
#   '5. volume': '1018038.65060000',
#   '6. market cap (USD)': '1018038.65060000'},
#  '2022-07-09': {'1a. open (USD)': '1214.03000000',
#   '1b. open (USD)': '1214.03000000',
#   '2a. high (USD)': '1235.40000000',
#   '2b. high (USD)': '1235.40000000',
#   '3a. low (USD)': '1204.67000000',
#   '3b. low (USD)': '1204.67000000',
#   '4a. close (USD)': '1217.02000000',
#   '4b. close (USD)': '1217.02000000',
#   '5. volume': '576337.18090000',
#   '6. market cap (USD)': '576337.18090000'},
#  '2022-07-08': {'1a. open (USD)': '1237.49000000',
#   '1b. open (USD)': '1237.49000000',
#   '2a. high (USD)': '1276.46000000',
#   '2b. high (USD)': '1276.46000000',
#   '3a. low (USD)': '1193.15000000',
#   '3b. low (USD)': '1193.15000000',
#   '4a. close (USD)': '1214.04000000',
#   '4b. close (USD)': '1214.04000000',
#   '5. volume': '1189518.36310000',
#   '6. market cap (USD)': '1189518.36310000'},
#  '2022-07-07': {'1a. open (USD)': '1186.57000000',
#   '1b. open (USD)': '1186.57000000',
#   '2a. high (USD)': '1254.29000000',
#   '2b. high (USD)': '1254.29000000',
#   '3a. low (USD)': '1163.18000000',
#   '3b. low (USD)': '1163.18000000',
#   '4a. close (USD)': '1237.49000000',
#   '4b. close (USD)': '1237.49000000',
#   '5. volume': '1001316.07900000',
#   '6. market cap (USD)': '1001316.07900000'},
#  '2022-07-06': {'1a. open (USD)': '1132.51000000',
#   '1b. open (USD)': '1132.51000000',
#   '2a. high (USD)': '1205.00000000',
#   '2b. high (USD)': '1205.00000000',
#   '3a. low (USD)': '1111.44000000',
#   '3b. low (USD)': '1111.44000000',
#   '4a. close (USD)': '1186.57000000',
#   '4b. close (USD)': '1186.57000000',
#   '5. volume': '1211768.07570000',
#   '6. market cap (USD)': '1211768.07570000'},
#  '2022-07-05': {'1a. open (USD)': '1151.01000000',
#   '1b. open (USD)': '1151.01000000',
#   '2a. high (USD)': '1174.90000000',
#   '2b. high (USD)': '1174.90000000',
#   '3a. low (USD)': '1076.34000000',
#   '3b. low (USD)': '1076.34000000',
#   '4a. close (USD)': '1132.50000000',
#   '4b. close (USD)': '1132.50000000',
#   '5. volume': '1398961.44950000',
#   '6. market cap (USD)': '1398961.44950000'},
#  '2022-07-04': {'1a. open (USD)': '1074.26000000',
#   '1b. open (USD)': '1074.26000000',
#   '2a. high (USD)': '1160.90000000',
#   '2b. high (USD)': '1160.90000000',
#   '3a. low (USD)': '1045.37000000',
#   '3b. low (USD)': '1045.37000000',
#   '4a. close (USD)': '1151.00000000',
#   '4b. close (USD)': '1151.00000000',
#   '5. volume': '1150108.98610000',
#   '6. market cap (USD)': '1150108.98610000'},
#  '2022-07-03': {'1a. open (USD)': '1067.01000000',
#   '1b. open (USD)': '1067.01000000',
#   '2a. high (USD)': '1088.34000000',
#   '2b. high (USD)': '1088.34000000',
#   '3a. low (USD)': '1040.78000000',
#   '3b. low (USD)': '1040.78000000',
#   '4a. close (USD)': '1074.26000000',
#   '4b. close (USD)': '1074.26000000',
#   '5. volume': '644746.33370000',
#   '6. market cap (USD)': '644746.33370000'},
#  '2022-07-02': {'1a. open (USD)': '1059.73000000',
#   '1b. open (USD)': '1059.73000000',
#   '2a. high (USD)': '1078.88000000',
#   '2b. high (USD)': '1078.88000000',
#   '3a. low (USD)': '1028.29000000',
#   '3b. low (USD)': '1028.29000000',
#   '4a. close (USD)': '1067.01000000',
#   '4b. close (USD)': '1067.01000000',
#   '5. volume': '714812.08040000',
#   '6. market cap (USD)': '714812.08040000'},
#  '2022-07-01': {'1a. open (USD)': '1071.02000000',
#   '1b. open (USD)': '1071.02000000',
#   '2a. high (USD)': '1117.00000000',
#   '2b. high (USD)': '1117.00000000',
#   '3a. low (USD)': '1033.44000000',
#   '3b. low (USD)': '1033.44000000',
#   '4a. close (USD)': '1059.73000000',
#   '4b. close (USD)': '1059.73000000',
#   '5. volume': '1562255.14390000',
#   '6. market cap (USD)': '1562255.14390000'},
#  '2022-06-30': {'1a. open (USD)': '1100.21000000',
#   '1b. open (USD)': '1100.21000000',
#   '2a. high (USD)': '1106.62000000',
#   '2b. high (USD)': '1106.62000000',
#   '3a. low (USD)': '998.00000000',
#   '3b. low (USD)': '998.00000000',
#   '4a. close (USD)': '1071.01000000',
#   '4b. close (USD)': '1071.01000000',
#   '5. volume': '1420670.36560000',
#   '6. market cap (USD)': '1420670.36560000'},
#  '2022-06-29': {'1a. open (USD)': '1144.05000000',
#   '1b. open (USD)': '1144.05000000',
#   '2a. high (USD)': '1156.80000000',
#   '2b. high (USD)': '1156.80000000',
#   '3a. low (USD)': '1087.42000000',
#   '3b. low (USD)': '1087.42000000',
#   '4a. close (USD)': '1100.21000000',
#   '4b. close (USD)': '1100.21000000',
#   '5. volume': '1295517.79600000',
#   '6. market cap (USD)': '1295517.79600000'},
#  '2022-06-28': {'1a. open (USD)': '1192.51000000',
#   '1b. open (USD)': '1192.51000000',
#   '2a. high (USD)': '1237.99000000',
#   '2b. high (USD)': '1237.99000000',
#   '3a. low (USD)': '1136.32000000',
#   '3b. low (USD)': '1136.32000000',
#   '4a. close (USD)': '1144.05000000',
#   '4b. close (USD)': '1144.05000000',
#   '5. volume': '1104065.22110000',
#   '6. market cap (USD)': '1104065.22110000'},
#  '2022-06-27': {'1a. open (USD)': '1197.79000000',
#   '1b. open (USD)': '1197.79000000',
#   '2a. high (USD)': '1238.93000000',
#   '2b. high (USD)': '1238.93000000',
#   '3a. low (USD)': '1172.49000000',
#   '3b. low (USD)': '1172.49000000',
#   '4a. close (USD)': '1192.51000000',
#   '4b. close (USD)': '1192.51000000',
#   '5. volume': '868734.20610000',
#   '6. market cap (USD)': '868734.20610000'},
#  '2022-06-26': {'1a. open (USD)': '1242.31000000',
#   '1b. open (USD)': '1242.31000000',
#   '2a. high (USD)': '1280.00000000',
#   '2b. high (USD)': '1280.00000000',
#   '3a. low (USD)': '1194.60000000',
#   '3b. low (USD)': '1194.60000000',
#   '4a. close (USD)': '1197.79000000',
#   '4b. close (USD)': '1197.79000000',
#   '5. volume': '884184.27300000',
#   '6. market cap (USD)': '884184.27300000'},
#  '2022-06-25': {'1a. open (USD)': '1225.02000000',
#   '1b. open (USD)': '1225.02000000',
#   '2a. high (USD)': '1256.77000000',
#   '2b. high (USD)': '1256.77000000',
#   '3a. low (USD)': '1180.00000000',
#   '3b. low (USD)': '1180.00000000',
#   '4a. close (USD)': '1242.36000000',
#   '4b. close (USD)': '1242.36000000',
#   '5. volume': '861986.61770000',
#   '6. market cap (USD)': '861986.61770000'},
#  '2022-06-24': {'1a. open (USD)': '1144.71000000',
#   '1b. open (USD)': '1144.71000000',
#   '2a. high (USD)': '1245.43000000',
#   '2b. high (USD)': '1245.43000000',
#   '3a. low (USD)': '1132.00000000',
#   '3b. low (USD)': '1132.00000000',
#   '4a. close (USD)': '1225.02000000',
#   '4b. close (USD)': '1225.02000000',
#   '5. volume': '1337137.48300000',
#   '6. market cap (USD)': '1337137.48300000'},
#  '2022-06-23': {'1a. open (USD)': '1050.19000000',
#   '1b. open (USD)': '1050.19000000',
#   '2a. high (USD)': '1155.00000000',
#   '2b. high (USD)': '1155.00000000',
#   '3a. low (USD)': '1045.30000000',
#   '3b. low (USD)': '1045.30000000',
#   '4a. close (USD)': '1144.72000000',
#   '4b. close (USD)': '1144.72000000',
#   '5. volume': '1278257.08990000',
#   '6. market cap (USD)': '1278257.08990000'},
#  '2022-06-22': {'1a. open (USD)': '1125.86000000',
#   '1b. open (USD)': '1125.86000000',
#   '2a. high (USD)': '1127.33000000',
#   '2b. high (USD)': '1127.33000000',
#   '3a. low (USD)': '1043.65000000',
#   '3b. low (USD)': '1043.65000000',
#   '4a. close (USD)': '1050.19000000',
#   '4b. close (USD)': '1050.19000000',
#   '5. volume': '1306959.85930000',
#   '6. market cap (USD)': '1306959.85930000'},
#  '2022-06-21': {'1a. open (USD)': '1128.24000000',
#   '1b. open (USD)': '1128.24000000',
#   '2a. high (USD)': '1194.00000000',
#   '2b. high (USD)': '1194.00000000',
#   '3a. low (USD)': '1109.23000000',
#   '3b. low (USD)': '1109.23000000',
#   '4a. close (USD)': '1125.85000000',
#   '4b. close (USD)': '1125.85000000',
#   '5. volume': '1306095.37570000',
#   '6. market cap (USD)': '1306095.37570000'},
#  '2022-06-20': {'1a. open (USD)': '1128.53000000',
#   '1b. open (USD)': '1128.53000000',
#   '2a. high (USD)': '1170.00000000',
#   '2b. high (USD)': '1170.00000000',
#   '3a. low (USD)': '1053.00000000',
#   '3b. low (USD)': '1053.00000000',
#   '4a. close (USD)': '1128.24000000',
#   '4b. close (USD)': '1128.24000000',
#   '5. volume': '1721772.91320000',
#   '6. market cap (USD)': '1721772.91320000'},
#  '2022-06-19': {'1a. open (USD)': '995.12000000',
#   '1b. open (USD)': '995.12000000',
#   '2a. high (USD)': '1158.62000000',
#   '2b. high (USD)': '1158.62000000',
#   '3a. low (USD)': '936.15000000',
#   '3b. low (USD)': '936.15000000',
#   '4a. close (USD)': '1128.53000000',
#   '4b. close (USD)': '1128.53000000',
#   '5. volume': '2018599.44990000',
#   '6. market cap (USD)': '2018599.44990000'},
#  '2022-06-18': {'1a. open (USD)': '1086.93000000',
#   '1b. open (USD)': '1086.93000000',
#   '2a. high (USD)': '1097.58000000',
#   '2b. high (USD)': '1097.58000000',
#   '3a. low (USD)': '881.56000000',
#   '3b. low (USD)': '881.56000000',
#   '4a. close (USD)': '995.13000000',
#   '4b. close (USD)': '995.13000000',
#   '5. volume': '2308983.51870000',
#   '6. market cap (USD)': '2308983.51870000'},
#  '2022-06-17': {'1a. open (USD)': '1068.50000000',
#   '1b. open (USD)': '1068.50000000',
#   '2a. high (USD)': '1118.00000000',
#   '2b. high (USD)': '1118.00000000',
#   '3a. low (USD)': '1051.11000000',
#   '3b. low (USD)': '1051.11000000',
#   '4a. close (USD)': '1086.94000000',
#   '4b. close (USD)': '1086.94000000',
#   '5. volume': '1220677.94910000',
#   '6. market cap (USD)': '1220677.94910000'},
#  '2022-06-16': {'1a. open (USD)': '1237.53000000',
#   '1b. open (USD)': '1237.53000000',
#   '2a. high (USD)': '1257.85000000',
#   '2b. high (USD)': '1257.85000000',
#   '3a. low (USD)': '1051.55000000',
#   '3b. low (USD)': '1051.55000000',
#   '4a. close (USD)': '1068.50000000',
#   '4b. close (USD)': '1068.50000000',
#   '5. volume': '1447386.83040000',
#   '6. market cap (USD)': '1447386.83040000'},
#  '2022-06-15': {'1a. open (USD)': '1208.90000000',
#   '1b. open (USD)': '1208.90000000',
#   '2a. high (USD)': '1250.00000000',
#   '2b. high (USD)': '1250.00000000',
#   '3a. low (USD)': '1014.40000000',
#   '3b. low (USD)': '1014.40000000',
#   '4a. close (USD)': '1237.52000000',
#   '4b. close (USD)': '1237.52000000',
#   '5. volume': '3114823.13621000',
#   '6. market cap (USD)': '3114823.13621000'},
#  '2022-06-14': {'1a. open (USD)': '1209.35000000',
#   '1b. open (USD)': '1209.35000000',
#   '2a. high (USD)': '1268.45000000',
#   '2b. high (USD)': '1268.45000000',
#   '3a. low (USD)': '1075.80000000',
#   '3b. low (USD)': '1075.80000000',
#   '4a. close (USD)': '1208.90000000',
#   '4b. close (USD)': '1208.90000000',
#   '5. volume': '2716493.80131000',
#   '6. market cap (USD)': '2716493.80131000'},
#  '2022-06-13': {'1a. open (USD)': '1434.84000000',
#   '1b. open (USD)': '1434.84000000',
#   '2a. high (USD)': '1455.00000000',
#   '2b. high (USD)': '1455.00000000',
#   '3a. low (USD)': '1165.45000000',
#   '3b. low (USD)': '1165.45000000',
#   '4a. close (USD)': '1209.82000000',
#   '4b. close (USD)': '1209.82000000',
#   '5. volume': '3626351.66536000',
#   '6. market cap (USD)': '3626351.66536000'},
#  '2022-06-12': {'1a. open (USD)': '1532.89000000',
#   '1b. open (USD)': '1532.89000000',
#   '2a. high (USD)': '1547.00000000',
#   '2b. high (USD)': '1547.00000000',
#   '3a. low (USD)': '1423.00000000',
#   '3b. low (USD)': '1423.00000000',
#   '4a. close (USD)': '1434.84000000',
#   '4b. close (USD)': '1434.84000000',
#   '5. volume': '1563225.37018000',
#   '6. market cap (USD)': '1563225.37018000'},
#  '2022-06-11': {'1a. open (USD)': '1662.91000000',
#   '1b. open (USD)': '1662.91000000',
#   '2a. high (USD)': '1682.21000000',
#   '2b. high (USD)': '1682.21000000',
#   '3a. low (USD)': '1496.74000000',
#   '3b. low (USD)': '1496.74000000',
#   '4a. close (USD)': '1532.89000000',
#   '4b. close (USD)': '1532.89000000',
#   '5. volume': '1220325.25420000',
#   '6. market cap (USD)': '1220325.25420000'},
#  '2022-06-10': {'1a. open (USD)': '1788.80000000',
#   '1b. open (USD)': '1788.80000000',
#   '2a. high (USD)': '1804.32000000',
#   '2b. high (USD)': '1804.32000000',
#   '3a. low (USD)': '1655.93000000',
#   '3b. low (USD)': '1655.93000000',
#   '4a. close (USD)': '1662.91000000',
#   '4b. close (USD)': '1662.91000000',
#   '5. volume': '955035.79239000',
#   '6. market cap (USD)': '955035.79239000'},
#  '2022-06-09': {'1a. open (USD)': '1791.88000000',
#   '1b. open (USD)': '1791.88000000',
#   '2a. high (USD)': '1833.00000000',
#   '2b. high (USD)': '1833.00000000',
#   '3a. low (USD)': '1777.33000000',
#   '3b. low (USD)': '1777.33000000',
#   '4a. close (USD)': '1788.81000000',
#   '4b. close (USD)': '1788.81000000',
#   '5. volume': '535310.96180000',
#   '6. market cap (USD)': '535310.96180000'},
#  '2022-06-08': {'1a. open (USD)': '1813.33000000',
#   '1b. open (USD)': '1813.33000000',
#   '2a. high (USD)': '1838.77000000',
#   '2b. high (USD)': '1838.77000000',
#   '3a. low (USD)': '1765.28000000',
#   '3b. low (USD)': '1765.28000000',
#   '4a. close (USD)': '1791.88000000',
#   '4b. close (USD)': '1791.88000000',
#   '5. volume': '941510.13730000',
#   '6. market cap (USD)': '941510.13730000'},
#  '2022-06-07': {'1a. open (USD)': '1859.84000000',
#   '1b. open (USD)': '1859.84000000',
#   '2a. high (USD)': '1874.98000000',
#   '2b. high (USD)': '1874.98000000',
#   '3a. low (USD)': '1725.13000000',
#   '3b. low (USD)': '1725.13000000',
#   '4a. close (USD)': '1813.33000000',
#   '4b. close (USD)': '1813.33000000',
#   '5. volume': '1397598.22880000',
#   '6. market cap (USD)': '1397598.22880000'},
#  '2022-06-06': {'1a. open (USD)': '1806.22000000',
#   '1b. open (USD)': '1806.22000000',
#   '2a. high (USD)': '1920.00000000',
#   '2b. high (USD)': '1920.00000000',
#   '3a. low (USD)': '1804.35000000',
#   '3b. low (USD)': '1804.35000000',
#   '4a. close (USD)': '1859.84000000',
#   '4b. close (USD)': '1859.84000000',
#   '5. volume': '804250.35670000',
#   '6. market cap (USD)': '804250.35670000'},
#  '2022-06-05': {'1a. open (USD)': '1804.58000000',
#   '1b. open (USD)': '1804.58000000',
#   '2a. high (USD)': '1830.17000000',
#   '2b. high (USD)': '1830.17000000',
#   '3a. low (USD)': '1773.05000000',
#   '3b. low (USD)': '1773.05000000',
#   '4a. close (USD)': '1806.23000000',
#   '4b. close (USD)': '1806.23000000',
#   '5. volume': '371974.50610000',
#   '6. market cap (USD)': '371974.50610000'},
#  '2022-06-04': {'1a. open (USD)': '1775.13000000',
#   '1b. open (USD)': '1775.13000000',
#   '2a. high (USD)': '1816.00000000',
#   '2b. high (USD)': '1816.00000000',
#   '3a. low (USD)': '1748.43000000',
#   '3b. low (USD)': '1748.43000000',
#   '4a. close (USD)': '1804.58000000',
#   '4b. close (USD)': '1804.58000000',
#   '5. volume': '388279.45790000',
#   '6. market cap (USD)': '388279.45790000'},
#  '2022-06-03': {'1a. open (USD)': '1834.09000000',
#   '1b. open (USD)': '1834.09000000',
#   '2a. high (USD)': '1843.91000000',
#   '2b. high (USD)': '1843.91000000',
#   '3a. low (USD)': '1737.00000000',
#   '3b. low (USD)': '1737.00000000',
#   '4a. close (USD)': '1775.12000000',
#   '4b. close (USD)': '1775.12000000',
#   '5. volume': '741282.53460000',
#   '6. market cap (USD)': '741282.53460000'},
#  '2022-06-02': {'1a. open (USD)': '1817.96000000',
#   '1b. open (USD)': '1817.96000000',
#   '2a. high (USD)': '1853.05000000',
#   '2b. high (USD)': '1853.05000000',
#   '3a. low (USD)': '1782.42000000',
#   '3b. low (USD)': '1782.42000000',
#   '4a. close (USD)': '1834.08000000',
#   '4b. close (USD)': '1834.08000000',
#   '5. volume': '788784.40170000',
#   '6. market cap (USD)': '788784.40170000'},
#  '2022-06-01': {'1a. open (USD)': '1941.90000000',
#   '1b. open (USD)': '1941.90000000',
#   '2a. high (USD)': '1972.58000000',
#   '2b. high (USD)': '1972.58000000',
#   '3a. low (USD)': '1763.75000000',
#   '3b. low (USD)': '1763.75000000',
#   '4a. close (USD)': '1817.95000000',
#   '4b. close (USD)': '1817.95000000',
#   '5. volume': '1037841.27060000',
#   '6. market cap (USD)': '1037841.27060000'},
#  '2022-05-31': {'1a. open (USD)': '1998.78000000',
#   '1b. open (USD)': '1998.78000000',
#   '2a. high (USD)': '2016.45000000',
#   '2b. high (USD)': '2016.45000000',
#   '3a. low (USD)': '1925.00000000',
#   '3b. low (USD)': '1925.00000000',
#   '4a. close (USD)': '1941.90000000',
#   '4b. close (USD)': '1941.90000000',
#   '5. volume': '751103.42260000',
#   '6. market cap (USD)': '751103.42260000'},
#  '2022-05-30': {'1a. open (USD)': '1813.64000000',
#   '1b. open (USD)': '1813.64000000',
#   '2a. high (USD)': '2013.00000000',
#   '2b. high (USD)': '2013.00000000',
#   '3a. low (USD)': '1803.18000000',
#   '3b. low (USD)': '1803.18000000',
#   '4a. close (USD)': '1998.78000000',
#   '4b. close (USD)': '1998.78000000',
#   '5. volume': '814922.83590000',
#   '6. market cap (USD)': '814922.83590000'},
#  '2022-05-29': {'1a. open (USD)': '1792.21000000',
#   '1b. open (USD)': '1792.21000000',
#   '2a. high (USD)': '1827.40000000',
#   '2b. high (USD)': '1827.40000000',
#   '3a. low (USD)': '1759.96000000',
#   '3b. low (USD)': '1759.96000000',
#   '4a. close (USD)': '1813.64000000',
#   '4b. close (USD)': '1813.64000000',
#   '5. volume': '432430.61100000',
#   '6. market cap (USD)': '432430.61100000'},
#  '2022-05-28': {'1a. open (USD)': '1727.26000000',
#   '1b. open (USD)': '1727.26000000',
#   '2a. high (USD)': '1808.98000000',
#   '2b. high (USD)': '1808.98000000',
#   '3a. low (USD)': '1722.26000000',
#   '3b. low (USD)': '1722.26000000',
#   '4a. close (USD)': '1792.22000000',
#   '4b. close (USD)': '1792.22000000',
#   '5. volume': '558271.18180000',
#   '6. market cap (USD)': '558271.18180000'},
#  '2022-05-27': {'1a. open (USD)': '1792.24000000',
#   '1b. open (USD)': '1792.24000000',
#   '2a. high (USD)': '1822.26000000',
#   '2b. high (USD)': '1822.26000000',
#   '3a. low (USD)': '1703.00000000',
#   '3b. low (USD)': '1703.00000000',
#   '4a. close (USD)': '1727.27000000',
#   '4b. close (USD)': '1727.27000000',
#   '5. volume': '1296693.28537000',
#   '6. market cap (USD)': '1296693.28537000'},
#  '2022-05-26': {'1a. open (USD)': '1942.64000000',
#   '1b. open (USD)': '1942.64000000',
#   '2a. high (USD)': '1966.01000000',
#   '2b. high (USD)': '1966.01000000',
#   '3a. low (USD)': '1735.00000000',
#   '3b. low (USD)': '1735.00000000',
#   '4a. close (USD)': '1792.23000000',
#   '4b. close (USD)': '1792.23000000',
#   '5. volume': '1168740.57514000',
#   '6. market cap (USD)': '1168740.57514000'},
#  '2022-05-25': {'1a. open (USD)': '1979.40000000',
#   '1b. open (USD)': '1979.40000000',
#   '2a. high (USD)': '2022.34000000',
#   '2b. high (USD)': '2022.34000000',
#   '3a. low (USD)': '1934.61000000',
#   '3b. low (USD)': '1934.61000000',
#   '4a. close (USD)': '1942.63000000',
#   '4b. close (USD)': '1942.63000000',
#   '5. volume': '524786.30910000',
#   '6. market cap (USD)': '524786.30910000'},
#  '2022-05-24': {'1a. open (USD)': '1973.33000000',
#   '1b. open (USD)': '1973.33000000',
#   '2a. high (USD)': '1993.83000000',
#   '2b. high (USD)': '1993.83000000',
#   '3a. low (USD)': '1913.02000000',
#   '3b. low (USD)': '1913.02000000',
#   '4a. close (USD)': '1979.41000000',
#   '4b. close (USD)': '1979.41000000',
#   '5. volume': '534096.97200000',
#   '6. market cap (USD)': '534096.97200000'},
#  '2022-05-23': {'1a. open (USD)': '2043.19000000',
#   '1b. open (USD)': '2043.19000000',
#   '2a. high (USD)': '2088.50000000',
#   '2b. high (USD)': '2088.50000000',
#   '3a. low (USD)': '1957.12000000',
#   '3b. low (USD)': '1957.12000000',
#   '4a. close (USD)': '1973.32000000',
#   '4b. close (USD)': '1973.32000000',
#   '5. volume': '636085.02240000',
#   '6. market cap (USD)': '636085.02240000'},
#  '2022-05-22': {'1a. open (USD)': '1975.06000000',
#   '1b. open (USD)': '1975.06000000',
#   '2a. high (USD)': '2056.41000000',
#   '2b. high (USD)': '2056.41000000',
#   '3a. low (USD)': '1966.33000000',
#   '3b. low (USD)': '1966.33000000',
#   '4a. close (USD)': '2043.19000000',
#   '4b. close (USD)': '2043.19000000',
#   '5. volume': '355735.19270000',
#   '6. market cap (USD)': '355735.19270000'},
#  '2022-05-21': {'1a. open (USD)': '1959.08000000',
#   '1b. open (USD)': '1959.08000000',
#   '2a. high (USD)': '1990.86000000',
#   '2b. high (USD)': '1990.86000000',
#   '3a. low (USD)': '1937.36000000',
#   '3b. low (USD)': '1937.36000000',
#   '4a. close (USD)': '1975.07000000',
#   '4b. close (USD)': '1975.07000000',
#   '5. volume': '238869.76320000',
#   '6. market cap (USD)': '238869.76320000'},
#  '2022-05-20': {'1a. open (USD)': '2019.55000000',
#   '1b. open (USD)': '2019.55000000',
#   '2a. high (USD)': '2064.00000000',
#   '2b. high (USD)': '2064.00000000',
#   '3a. low (USD)': '1923.00000000',
#   '3b. low (USD)': '1923.00000000',
#   '4a. close (USD)': '1959.08000000',
#   '4b. close (USD)': '1959.08000000',
#   '5. volume': '576981.53710000',
#   '6. market cap (USD)': '576981.53710000'},
#  '2022-05-19': {'1a. open (USD)': '1915.11000000',
#   '1b. open (USD)': '1915.11000000',
#   '2a. high (USD)': '2040.39000000',
#   '2b. high (USD)': '2040.39000000',
#   '3a. low (USD)': '1903.18000000',
#   '3b. low (USD)': '1903.18000000',
#   '4a. close (USD)': '2019.55000000',
#   '4b. close (USD)': '2019.55000000',
#   '5. volume': '741476.97940000',
#   '6. market cap (USD)': '741476.97940000'},
#  '2022-05-18': {'1a. open (USD)': '2090.72000000',
#   '1b. open (USD)': '2090.72000000',
#   '2a. high (USD)': '2110.72000000',
#   '2b. high (USD)': '2110.72000000',
#   '3a. low (USD)': '1908.00000000',
#   '3b. low (USD)': '1908.00000000',
#   '4a. close (USD)': '1915.11000000',
#   '4b. close (USD)': '1915.11000000',
#   '5. volume': '631577.23410000',
#   '6. market cap (USD)': '631577.23410000'},
#  '2022-05-17': {'1a. open (USD)': '2023.66000000',
#   '1b. open (USD)': '2023.66000000',
#   '2a. high (USD)': '2122.42000000',
#   '2b. high (USD)': '2122.42000000',
#   '3a. low (USD)': '2008.00000000',
#   '3b. low (USD)': '2008.00000000',
#   '4a. close (USD)': '2090.72000000',
#   '4b. close (USD)': '2090.72000000',
#   '5. volume': '568249.04480000',
#   '6. market cap (USD)': '568249.04480000'},
#  '2022-05-16': {'1a. open (USD)': '2145.29000000',
#   '1b. open (USD)': '2145.29000000',
#   '2a. high (USD)': '2145.29000000',
#   '2b. high (USD)': '2145.29000000',
#   '3a. low (USD)': '1979.12000000',
#   '3b. low (USD)': '1979.12000000',
#   '4a. close (USD)': '2023.66000000',
#   '4b. close (USD)': '2023.66000000',
#   '5. volume': '822070.85310000',
#   '6. market cap (USD)': '822070.85310000'},
#  '2022-05-15': {'1a. open (USD)': '2056.47000000',
#   '1b. open (USD)': '2056.47000000',
#   '2a. high (USD)': '2167.00000000',
#   '2b. high (USD)': '2167.00000000',
#   '3a. low (USD)': '2000.68000000',
#   '3b. low (USD)': '2000.68000000',
#   '4a. close (USD)': '2145.29000000',
#   '4b. close (USD)': '2145.29000000',
#   '5. volume': '514398.25870000',
#   '6. market cap (USD)': '514398.25870000'},
#  '2022-05-14': {'1a. open (USD)': '2009.69000000',
#   '1b. open (USD)': '2009.69000000',
#   '2a. high (USD)': '2070.06000000',
#   '2b. high (USD)': '2070.06000000',
#   '3a. low (USD)': '1951.21000000',
#   '3b. low (USD)': '1951.21000000',
#   '4a. close (USD)': '2056.48000000',
#   '4b. close (USD)': '2056.48000000',
#   '5. volume': '563788.30780000',
#   '6. market cap (USD)': '563788.30780000'},
#  '2022-05-13': {'1a. open (USD)': '1960.22000000',
#   '1b. open (USD)': '1960.22000000',
#   '2a. high (USD)': '2147.54000000',
#   '2b. high (USD)': '2147.54000000',
#   '3a. low (USD)': '1940.23000000',
#   '3b. low (USD)': '1940.23000000',
#   '4a. close (USD)': '2009.69000000',
#   '4b. close (USD)': '2009.69000000',
#   '5. volume': '1134042.33870000',
#   '6. market cap (USD)': '1134042.33870000'},
#  '2022-05-12': {'1a. open (USD)': '2084.99000000',
#   '1b. open (USD)': '2084.99000000',
#   '2a. high (USD)': '2195.00000000',
#   '2b. high (USD)': '2195.00000000',
#   '3a. low (USD)': '1800.00000000',
#   '3b. low (USD)': '1800.00000000',
#   '4a. close (USD)': '1960.22000000',
#   '4b. close (USD)': '1960.22000000',
#   '5. volume': '2305192.90836000',
#   '6. market cap (USD)': '2305192.90836000'},
#  '2022-05-11': {'1a. open (USD)': '2342.04000000',
#   '1b. open (USD)': '2342.04000000',
#   '2a. high (USD)': '2451.37000000',
#   '2b. high (USD)': '2451.37000000',
#   '3a. low (USD)': '2005.00000000',
#   '3b. low (USD)': '2005.00000000',
#   '4a. close (USD)': '2084.99000000',
#   '4b. close (USD)': '2084.99000000',
#   '5. volume': '2022864.83806000',
#   '6. market cap (USD)': '2022864.83806000'},
#  '2022-05-10': {'1a. open (USD)': '2229.00000000',
#   '1b. open (USD)': '2229.00000000',
#   '2a. high (USD)': '2457.34000000',
#   '2b. high (USD)': '2457.34000000',
#   '3a. low (USD)': '2200.00000000',
#   '3b. low (USD)': '2200.00000000',
#   '4a. close (USD)': '2342.05000000',
#   '4b. close (USD)': '2342.05000000',
#   '5. volume': '1550626.13870000',
#   '6. market cap (USD)': '1550626.13870000'},
#  '2022-05-09': {'1a. open (USD)': '2519.71000000',
#   '1b. open (USD)': '2519.71000000',
#   '2a. high (USD)': '2530.78000000',
#   '2b. high (USD)': '2530.78000000',
#   '3a. low (USD)': '2225.00000000',
#   '3b. low (USD)': '2225.00000000',
#   '4a. close (USD)': '2228.55000000',
#   '4b. close (USD)': '2228.55000000',
#   '5. volume': '1574924.97930000',
#   '6. market cap (USD)': '1574924.97930000'},
#  '2022-05-08': {'1a. open (USD)': '2635.35000000',
#   '1b. open (USD)': '2635.35000000',
#   '2a. high (USD)': '2642.00000000',
#   '2b. high (USD)': '2642.00000000',
#   '3a. low (USD)': '2484.00000000',
#   '3b. low (USD)': '2484.00000000',
#   '4a. close (USD)': '2519.71000000',
#   '4b. close (USD)': '2519.71000000',
#   '5. volume': '757615.34150000',
#   '6. market cap (USD)': '757615.34150000'},
#  '2022-05-07': {'1a. open (USD)': '2692.86000000',
#   '1b. open (USD)': '2692.86000000',
#   '2a. high (USD)': '2704.36000000',
#   '2b. high (USD)': '2704.36000000',
#   '3a. low (USD)': '2584.75000000',
#   '3b. low (USD)': '2584.75000000',
#   '4a. close (USD)': '2635.34000000',
#   '4b. close (USD)': '2635.34000000',
#   '5. volume': '371271.45320000',
#   '6. market cap (USD)': '371271.45320000'},
#  '2022-05-06': {'1a. open (USD)': '2747.96000000',
#   '1b. open (USD)': '2747.96000000',
#   '2a. high (USD)': '2758.18000000',
#   '2b. high (USD)': '2758.18000000',
#   '3a. low (USD)': '2632.95000000',
#   '3b. low (USD)': '2632.95000000',
#   '4a. close (USD)': '2692.85000000',
#   '4b. close (USD)': '2692.85000000',
#   '5. volume': '711449.32340000',
#   '6. market cap (USD)': '711449.32340000'},
#  '2022-05-05': {'1a. open (USD)': '2940.65000000',
#   '1b. open (USD)': '2940.65000000',
#   '2a. high (USD)': '2954.65000000',
#   '2b. high (USD)': '2954.65000000',
#   '3a. low (USD)': '2683.00000000',
#   '3b. low (USD)': '2683.00000000',
#   '4a. close (USD)': '2747.97000000',
#   '4b. close (USD)': '2747.97000000',
#   '5. volume': '734845.31940000',
#   '6. market cap (USD)': '734845.31940000'},
#  '2022-05-04': {'1a. open (USD)': '2781.70000000',
#   '1b. open (USD)': '2781.70000000',
#   '2a. high (USD)': '2965.85000000',
#   '2b. high (USD)': '2965.85000000',
#   '3a. low (USD)': '2771.74000000',
#   '3b. low (USD)': '2771.74000000',
#   '4a. close (USD)': '2940.64000000',
#   '4b. close (USD)': '2940.64000000',
#   '5. volume': '548738.06680000',
#   '6. market cap (USD)': '548738.06680000'},
#  '2022-05-03': {'1a. open (USD)': '2856.54000000',
#   '1b. open (USD)': '2856.54000000',
#   '2a. high (USD)': '2861.47000000',
#   '2b. high (USD)': '2861.47000000',
#   '3a. low (USD)': '2755.19000000',
#   '3b. low (USD)': '2755.19000000',
#   '4a. close (USD)': '2781.70000000',
#   '4b. close (USD)': '2781.70000000',
#   '5. volume': '371331.17960000',
#   '6. market cap (USD)': '371331.17960000'},
#  '2022-05-02': {'1a. open (USD)': '2824.81000000',
#   '1b. open (USD)': '2824.81000000',
#   '2a. high (USD)': '2894.22000000',
#   '2b. high (USD)': '2894.22000000',
#   '3a. low (USD)': '2778.78000000',
#   '3b. low (USD)': '2778.78000000',
#   '4a. close (USD)': '2856.54000000',
#   '4b. close (USD)': '2856.54000000',
#   '5. volume': '521706.85670000',
#   '6. market cap (USD)': '521706.85670000'},
#  '2022-05-01': {'1a. open (USD)': '2726.67000000',
#   '1b. open (USD)': '2726.67000000',
#   '2a. high (USD)': '2849.90000000',
#   '2b. high (USD)': '2849.90000000',
#   '3a. low (USD)': '2716.13000000',
#   '3b. low (USD)': '2716.13000000',
#   '4a. close (USD)': '2824.81000000',
#   '4b. close (USD)': '2824.81000000',
#   '5. volume': '442544.87920000',
#   '6. market cap (USD)': '442544.87920000'},
#  '2022-04-30': {'1a. open (USD)': '2817.13000000',
#   '1b. open (USD)': '2817.13000000',
#   '2a. high (USD)': '2841.63000000',
#   '2b. high (USD)': '2841.63000000',
#   '3a. low (USD)': '2709.26000000',
#   '3b. low (USD)': '2709.26000000',
#   '4a. close (USD)': '2726.66000000',
#   '4b. close (USD)': '2726.66000000',
#   '5. volume': '367757.24690000',
#   '6. market cap (USD)': '367757.24690000'},
#  '2022-04-29': {'1a. open (USD)': '2936.92000000',
#   '1b. open (USD)': '2936.92000000',
#   '2a. high (USD)': '2946.46000000',
#   '2b. high (USD)': '2946.46000000',
#   '3a. low (USD)': '2776.63000000',
#   '3b. low (USD)': '2776.63000000',
#   '4a. close (USD)': '2817.13000000',
#   '4b. close (USD)': '2817.13000000',
#   '5. volume': '525978.14700000',
#   '6. market cap (USD)': '525978.14700000'},
#  '2022-04-28': {'1a. open (USD)': '2888.95000000',
#   '1b. open (USD)': '2888.95000000',
#   '2a. high (USD)': '2980.00000000',
#   '2b. high (USD)': '2980.00000000',
#   '3a. low (USD)': '2853.83000000',
#   '3b. low (USD)': '2853.83000000',
#   '4a. close (USD)': '2936.93000000',
#   '4b. close (USD)': '2936.93000000',
#   '5. volume': '537392.99780000',
#   '6. market cap (USD)': '537392.99780000'},
#  '2022-04-27': {'1a. open (USD)': '2809.68000000',
#   '1b. open (USD)': '2809.68000000',
#   '2a. high (USD)': '2919.87000000',
#   '2b. high (USD)': '2919.87000000',
#   '3a. low (USD)': '2794.46000000',
#   '3b. low (USD)': '2794.46000000',
#   '4a. close (USD)': '2888.96000000',
#   '4b. close (USD)': '2888.96000000',
#   '5. volume': '488951.24160000',
#   '6. market cap (USD)': '488951.24160000'},
#  '2022-04-26': {'1a. open (USD)': '3006.63000000',
#   '1b. open (USD)': '3006.63000000',
#   '2a. high (USD)': '3039.54000000',
#   '2b. high (USD)': '3039.54000000',
#   '3a. low (USD)': '2767.00000000',
#   '3b. low (USD)': '2767.00000000',
#   '4a. close (USD)': '2809.67000000',
#   '4b. close (USD)': '2809.67000000',
#   '5. volume': '531184.35040000',
#   '6. market cap (USD)': '531184.35040000'},
#  '2022-04-25': {'1a. open (USD)': '2920.99000000',
#   '1b. open (USD)': '2920.99000000',
#   '2a. high (USD)': '3025.65000000',
#   '2b. high (USD)': '3025.65000000',
#   '3a. low (USD)': '2797.01000000',
#   '3b. low (USD)': '2797.01000000',
#   '4a. close (USD)': '3006.62000000',
#   '4b. close (USD)': '3006.62000000',
#   '5. volume': '619198.36160000',
#   '6. market cap (USD)': '619198.36160000'},
#  '2022-04-24': {'1a. open (USD)': '2933.04000000',
#   '1b. open (USD)': '2933.04000000',
#   '2a. high (USD)': '2967.06000000',
#   '2b. high (USD)': '2967.06000000',
#   '3a. low (USD)': '2912.09000000',
#   '3b. low (USD)': '2912.09000000',
#   '4a. close (USD)': '2921.00000000',
#   '4b. close (USD)': '2921.00000000',
#   '5. volume': '218957.02220000',
#   '6. market cap (USD)': '218957.02220000'},
#  '2022-04-23': {'1a. open (USD)': '2962.39000000',
#   '1b. open (USD)': '2962.39000000',
#   '2a. high (USD)': '2978.03000000',
#   '2b. high (USD)': '2978.03000000',
#   '3a. low (USD)': '2913.89000000',
#   '3b. low (USD)': '2913.89000000',
#   '4a. close (USD)': '2933.03000000',
#   '4b. close (USD)': '2933.03000000',
#   '5. volume': '187576.73240000',
#   '6. market cap (USD)': '187576.73240000'},
#  '2022-04-22': {'1a. open (USD)': '2983.57000000',
#   '1b. open (USD)': '2983.57000000',
#   '2a. high (USD)': '3034.32000000',
#   '2b. high (USD)': '3034.32000000',
#   '3a. low (USD)': '2930.35000000',
#   '3b. low (USD)': '2930.35000000',
#   '4a. close (USD)': '2962.39000000',
#   '4b. close (USD)': '2962.39000000',
#   '5. volume': '452433.08200000',
#   '6. market cap (USD)': '452433.08200000'},
#  '2022-04-21': {'1a. open (USD)': '3076.03000000',
#   '1b. open (USD)': '3076.03000000',
#   '2a. high (USD)': '3180.00000000',
#   '2b. high (USD)': '3180.00000000',
#   '3a. low (USD)': '2942.31000000',
#   '3b. low (USD)': '2942.31000000',
#   '4a. close (USD)': '2983.58000000',
#   '4b. close (USD)': '2983.58000000',
#   '5. volume': '562699.69700000',
#   '6. market cap (USD)': '562699.69700000'},
#  '2022-04-20': {'1a. open (USD)': '3101.74000000',
#   '1b. open (USD)': '3101.74000000',
#   '2a. high (USD)': '3166.50000000',
#   '2b. high (USD)': '3166.50000000',
#   '3a. low (USD)': '3036.45000000',
#   '3b. low (USD)': '3036.45000000',
#   '4a. close (USD)': '3076.04000000',
#   '4b. close (USD)': '3076.04000000',
#   '5. volume': '415000.06850000',
#   '6. market cap (USD)': '415000.06850000'},
#  '2022-04-19': {'1a. open (USD)': '3055.56000000',
#   '1b. open (USD)': '3055.56000000',
#   '2a. high (USD)': '3131.00000000',
#   '2b. high (USD)': '3131.00000000',
#   '3a. low (USD)': '3030.34000000',
#   '3b. low (USD)': '3030.34000000',
#   '4a. close (USD)': '3101.77000000',
#   '4b. close (USD)': '3101.77000000',
#   '5. volume': '359375.00380000',
#   '6. market cap (USD)': '359375.00380000'},
#  '2022-04-18': {'1a. open (USD)': '2988.07000000',
# ...
#   '1b. open (USD)': '134.37000000',
#   '2a. high (USD)': '135.85000000',
#   '2b. high (USD)': '135.85000000',
#   '3a. low (USD)': '132.50000000',
#   '3b. low (USD)': '132.50000000',
#   '4a. close (USD)': '134.20000000',
#   '4b. close (USD)': '134.20000000',
#   '5. volume': '184276.17102000',
#   '6. market cap (USD)': '184276.17102000'},
#  '2020-01-03': {'1a. open (USD)': '127.19000000',
#   '1b. open (USD)': '127.19000000',
#   '2a. high (USD)': '135.14000000',
#   '2b. high (USD)': '135.14000000',
#   '3a. low (USD)': '125.88000000',
#   '3b. low (USD)': '125.88000000',
#   '4a. close (USD)': '134.35000000',
#   '4b. close (USD)': '134.35000000',
#   '5. volume': '413055.18895000',
#   '6. market cap (USD)': '413055.18895000'},
#  '2020-01-02': {'1a. open (USD)': '130.72000000',
#   '1b. open (USD)': '130.72000000',
#   '2a. high (USD)': '130.78000000',
#   '2b. high (USD)': '130.78000000',
#   '3a. low (USD)': '126.38000000',
#   '3b. low (USD)': '126.38000000',
#   '4a. close (USD)': '127.19000000',
#   '4b. close (USD)': '127.19000000',
#   '5. volume': '213757.05806000',
#   '6. market cap (USD)': '213757.05806000'},
#  '2020-01-01': {'1a. open (USD)': '129.16000000',
#   '1b. open (USD)': '129.16000000',
#   '2a. high (USD)': '133.05000000',
#   '2b. high (USD)': '133.05000000',
#   '3a. low (USD)': '128.68000000',
#   '3b. low (USD)': '128.68000000',
#   '4a. close (USD)': '130.77000000',
#   '4b. close (USD)': '130.77000000',
#   '5. volume': '144770.52197000',
#   '6. market cap (USD)': '144770.52197000'},
#  '2019-12-31': {'1a. open (USD)': '131.61000000',
#   '1b. open (USD)': '131.61000000',
#   '2a. high (USD)': '133.68000000',
#   '2b. high (USD)': '133.68000000',
#   '3a. low (USD)': '128.17000000',
#   '3b. low (USD)': '128.17000000',
#   '4a. close (USD)': '129.16000000',
#   '4b. close (USD)': '129.16000000',
#   '5. volume': '264933.98418000',
#   '6. market cap (USD)': '264933.98418000'},
#  '2019-12-30': {'1a. open (USD)': '134.36000000',
#   '1b. open (USD)': '134.36000000',
#   '2a. high (USD)': '136.24000000',
#   '2b. high (USD)': '136.24000000',
#   '3a. low (USD)': '130.30000000',
#   '3b. low (USD)': '130.30000000',
#   '4a. close (USD)': '131.59000000',
#   '4b. close (USD)': '131.59000000',
#   '5. volume': '320347.21956000',
#   '6. market cap (USD)': '320347.21956000'},
#  '2019-12-29': {'1a. open (USD)': '128.11000000',
#   '1b. open (USD)': '128.11000000',
#   '2a. high (USD)': '138.07000000',
#   '2b. high (USD)': '138.07000000',
#   '3a. low (USD)': '127.52000000',
#   '3b. low (USD)': '127.52000000',
#   '4a. close (USD)': '134.36000000',
#   '4b. close (USD)': '134.36000000',
#   '5. volume': '316347.26666000',
#   '6. market cap (USD)': '316347.26666000'},
#  '2019-12-28': {'1a. open (USD)': '126.28000000',
#   '1b. open (USD)': '126.28000000',
#   '2a. high (USD)': '129.68000000',
#   '2b. high (USD)': '129.68000000',
#   '3a. low (USD)': '125.84000000',
#   '3b. low (USD)': '125.84000000',
#   '4a. close (USD)': '128.11000000',
#   '4b. close (USD)': '128.11000000',
#   '5. volume': '196893.52277000',
#   '6. market cap (USD)': '196893.52277000'},
#  '2019-12-27': {'1a. open (USD)': '125.58000000',
#   '1b. open (USD)': '125.58000000',
#   '2a. high (USD)': '127.10000000',
#   '2b. high (USD)': '127.10000000',
#   '3a. low (USD)': '121.91000000',
#   '3b. low (USD)': '121.91000000',
#   '4a. close (USD)': '126.29000000',
#   '4b. close (USD)': '126.29000000',
#   '5. volume': '240012.37451000',
#   '6. market cap (USD)': '240012.37451000'},
#  '2019-12-26': {'1a. open (USD)': '125.09000000',
#   '1b. open (USD)': '125.09000000',
#   '2a. high (USD)': '132.26000000',
#   '2b. high (USD)': '132.26000000',
#   '3a. low (USD)': '124.32000000',
#   '3b. low (USD)': '124.32000000',
#   '4a. close (USD)': '125.58000000',
#   '4b. close (USD)': '125.58000000',
#   '5. volume': '274986.52097000',
#   '6. market cap (USD)': '274986.52097000'},
#  '2019-12-25': {'1a. open (USD)': '127.70000000',
#   '1b. open (USD)': '127.70000000',
#   '2a. high (USD)': '127.84000000',
#   '2b. high (USD)': '127.84000000',
#   '3a. low (USD)': '123.07000000',
#   '3b. low (USD)': '123.07000000',
#   '4a. close (USD)': '125.09000000',
#   '4b. close (USD)': '125.09000000',
#   '5. volume': '225004.49090000',
#   '6. market cap (USD)': '225004.49090000'},
#  '2019-12-24': {'1a. open (USD)': '127.80000000',
#   '1b. open (USD)': '127.80000000',
#   '2a. high (USD)': '129.69000000',
#   '2b. high (USD)': '129.69000000',
#   '3a. low (USD)': '126.61000000',
#   '3b. low (USD)': '126.61000000',
#   '4a. close (USD)': '127.75000000',
#   '4b. close (USD)': '127.75000000',
#   '5. volume': '200637.10098000',
#   '6. market cap (USD)': '200637.10098000'},
#  '2019-12-23': {'1a. open (USD)': '132.12000000',
#   '1b. open (USD)': '132.12000000',
#   '2a. high (USD)': '135.10000000',
#   '2b. high (USD)': '135.10000000',
#   '3a. low (USD)': '126.00000000',
#   '3b. low (USD)': '126.00000000',
#   '4a. close (USD)': '127.80000000',
#   '4b. close (USD)': '127.80000000',
#   '5. volume': '421600.75655000',
#   '6. market cap (USD)': '421600.75655000'},
#  '2019-12-22': {'1a. open (USD)': '127.00000000',
#   '1b. open (USD)': '127.00000000',
#   '2a. high (USD)': '133.07000000',
#   '2b. high (USD)': '133.07000000',
#   '3a. low (USD)': '126.82000000',
#   '3b. low (USD)': '126.82000000',
#   '4a. close (USD)': '132.09000000',
#   '4b. close (USD)': '132.09000000',
#   '5. volume': '253140.72413000',
#   '6. market cap (USD)': '253140.72413000'},
#  '2019-12-21': {'1a. open (USD)': '128.19000000',
#   '1b. open (USD)': '128.19000000',
#   '2a. high (USD)': '128.40000000',
#   '2b. high (USD)': '128.40000000',
#   '3a. low (USD)': '126.50000000',
#   '3b. low (USD)': '126.50000000',
#   '4a. close (USD)': '126.99000000',
#   '4b. close (USD)': '126.99000000',
#   '5. volume': '135196.11641000',
#   '6. market cap (USD)': '135196.11641000'},
#  '2019-12-20': {'1a. open (USD)': '128.10000000',
#   '1b. open (USD)': '128.10000000',
#   '2a. high (USD)': '129.39000000',
#   '2b. high (USD)': '129.39000000',
#   '3a. low (USD)': '125.84000000',
#   '3b. low (USD)': '125.84000000',
#   '4a. close (USD)': '128.19000000',
#   '4b. close (USD)': '128.19000000',
#   '5. volume': '213897.46730000',
#   '6. market cap (USD)': '213897.46730000'},
#  '2019-12-19': {'1a. open (USD)': '132.80000000',
#   '1b. open (USD)': '132.80000000',
#   '2a. high (USD)': '134.00000000',
#   '2b. high (USD)': '134.00000000',
#   '3a. low (USD)': '125.69000000',
#   '3b. low (USD)': '125.69000000',
#   '4a. close (USD)': '128.10000000',
#   '4b. close (USD)': '128.10000000',
#   '5. volume': '420674.81720000',
#   '6. market cap (USD)': '420674.81720000'},
#  '2019-12-18': {'1a. open (USD)': '121.88000000',
#   '1b. open (USD)': '121.88000000',
#   '2a. high (USD)': '134.87000000',
#   '2b. high (USD)': '134.87000000',
#   '3a. low (USD)': '116.26000000',
#   '3b. low (USD)': '116.26000000',
#   '4a. close (USD)': '132.78000000',
#   '4b. close (USD)': '132.78000000',
#   '5. volume': '884960.91334000',
#   '6. market cap (USD)': '884960.91334000'},
#  '2019-12-17': {'1a. open (USD)': '132.72000000',
#   '1b. open (USD)': '132.72000000',
#   '2a. high (USD)': '132.98000000',
#   '2b. high (USD)': '132.98000000',
#   '3a. low (USD)': '119.11000000',
#   '3b. low (USD)': '119.11000000',
#   '4a. close (USD)': '121.88000000',
#   '4b. close (USD)': '121.88000000',
#   '5. volume': '563257.36001000',
#   '6. market cap (USD)': '563257.36001000'},
#  '2019-12-16': {'1a. open (USD)': '142.46000000',
#   '1b. open (USD)': '142.46000000',
#   '2a. high (USD)': '142.72000000',
#   '2b. high (USD)': '142.72000000',
#   '3a. low (USD)': '127.93000000',
#   '3b. low (USD)': '127.93000000',
#   '4a. close (USD)': '132.73000000',
#   '4b. close (USD)': '132.73000000',
#   '5. volume': '471018.85942000',
#   '6. market cap (USD)': '471018.85942000'},
#  '2019-12-15': {'1a. open (USD)': '141.79000000',
#   '1b. open (USD)': '141.79000000',
#   '2a. high (USD)': '144.12000000',
#   '2b. high (USD)': '144.12000000',
#   '3a. low (USD)': '139.92000000',
#   '3b. low (USD)': '139.92000000',
#   '4a. close (USD)': '142.46000000',
#   '4b. close (USD)': '142.46000000',
#   '5. volume': '151189.65877000',
#   '6. market cap (USD)': '151189.65877000'},
#  '2019-12-14': {'1a. open (USD)': '144.80000000',
#   '1b. open (USD)': '144.80000000',
#   '2a. high (USD)': '145.07000000',
#   '2b. high (USD)': '145.07000000',
#   '3a. low (USD)': '141.18000000',
#   '3b. low (USD)': '141.18000000',
#   '4a. close (USD)': '141.79000000',
#   '4b. close (USD)': '141.79000000',
#   '5. volume': '126232.59201000',
#   '6. market cap (USD)': '126232.59201000'},
#  '2019-12-13': {'1a. open (USD)': '144.87000000',
#   '1b. open (USD)': '144.87000000',
#   '2a. high (USD)': '146.00000000',
#   '2b. high (USD)': '146.00000000',
#   '3a. low (USD)': '142.80000000',
#   '3b. low (USD)': '142.80000000',
#   '4a. close (USD)': '144.80000000',
#   '4b. close (USD)': '144.80000000',
#   '5. volume': '160695.18556000',
#   '6. market cap (USD)': '160695.18556000'},
#  '2019-12-12': {'1a. open (USD)': '143.41000000',
#   '1b. open (USD)': '143.41000000',
#   '2a. high (USD)': '145.85000000',
#   '2b. high (USD)': '145.85000000',
#   '3a. low (USD)': '139.24000000',
#   '3b. low (USD)': '139.24000000',
#   '4a. close (USD)': '144.87000000',
#   '4b. close (USD)': '144.87000000',
#   '5. volume': '261615.30437000',
#   '6. market cap (USD)': '261615.30437000'},
#  '2019-12-11': {'1a. open (USD)': '145.53000000',
#   '1b. open (USD)': '145.53000000',
#   '2a. high (USD)': '146.34000000',
#   '2b. high (USD)': '146.34000000',
#   '3a. low (USD)': '142.12000000',
#   '3b. low (USD)': '142.12000000',
#   '4a. close (USD)': '143.39000000',
#   '4b. close (USD)': '143.39000000',
#   '5. volume': '157843.10484000',
#   '6. market cap (USD)': '157843.10484000'},
#  '2019-12-10': {'1a. open (USD)': '147.40000000',
#   '1b. open (USD)': '147.40000000',
#   '2a. high (USD)': '148.57000000',
#   '2b. high (USD)': '148.57000000',
#   '3a. low (USD)': '143.81000000',
#   '3b. low (USD)': '143.81000000',
#   '4a. close (USD)': '145.56000000',
#   '4b. close (USD)': '145.56000000',
#   '5. volume': '203215.84937000',
#   '6. market cap (USD)': '203215.84937000'},
#  '2019-12-09': {'1a. open (USD)': '150.44000000',
#   '1b. open (USD)': '150.44000000',
#   '2a. high (USD)': '151.19000000',
#   '2b. high (USD)': '151.19000000',
#   '3a. low (USD)': '146.56000000',
#   '3b. low (USD)': '146.56000000',
#   '4a. close (USD)': '147.38000000',
#   '4b. close (USD)': '147.38000000',
#   '5. volume': '243775.99249000',
#   '6. market cap (USD)': '243775.99249000'},
#  '2019-12-08': {'1a. open (USD)': '147.16000000',
#   '1b. open (USD)': '147.16000000',
#   '2a. high (USD)': '151.62000000',
#   '2b. high (USD)': '151.62000000',
#   '3a. low (USD)': '146.11000000',
#   '3b. low (USD)': '146.11000000',
#   '4a. close (USD)': '150.44000000',
#   '4b. close (USD)': '150.44000000',
#   '5. volume': '205301.60260000',
#   '6. market cap (USD)': '205301.60260000'},
#  '2019-12-07': {'1a. open (USD)': '148.46000000',
#   '1b. open (USD)': '148.46000000',
#   '2a. high (USD)': '149.49000000',
#   '2b. high (USD)': '149.49000000',
#   '3a. low (USD)': '146.85000000',
#   '3b. low (USD)': '146.85000000',
#   '4a. close (USD)': '147.14000000',
#   '4b. close (USD)': '147.14000000',
#   '5. volume': '140471.68588000',
#   '6. market cap (USD)': '140471.68588000'},
#  '2019-12-06': {'1a. open (USD)': '148.11000000',
#   '1b. open (USD)': '148.11000000',
#   '2a. high (USD)': '149.77000000',
#   '2b. high (USD)': '149.77000000',
#   '3a. low (USD)': '145.74000000',
#   '3b. low (USD)': '145.74000000',
#   '4a. close (USD)': '148.45000000',
#   '4b. close (USD)': '148.45000000',
#   '5. volume': '220674.68581000',
#   '6. market cap (USD)': '220674.68581000'},
#  '2019-12-05': {'1a. open (USD)': '145.45000000',
#   '1b. open (USD)': '145.45000000',
#   '2a. high (USD)': '149.02000000',
#   '2b. high (USD)': '149.02000000',
#   '3a. low (USD)': '143.64000000',
#   '3b. low (USD)': '143.64000000',
#   '4a. close (USD)': '148.10000000',
#   '4b. close (USD)': '148.10000000',
#   '5. volume': '299073.53972000',
#   '6. market cap (USD)': '299073.53972000'},
#  '2019-12-04': {'1a. open (USD)': '147.19000000',
#   '1b. open (USD)': '147.19000000',
#   '2a. high (USD)': '151.98000000',
#   '2b. high (USD)': '151.98000000',
#   '3a. low (USD)': '143.15000000',
#   '3b. low (USD)': '143.15000000',
#   '4a. close (USD)': '145.38000000',
#   '4b. close (USD)': '145.38000000',
#   '5. volume': '434490.46521000',
#   '6. market cap (USD)': '434490.46521000'},
#  '2019-12-03': {'1a. open (USD)': '148.66000000',
#   '1b. open (USD)': '148.66000000',
#   '2a. high (USD)': '149.93000000',
#   '2b. high (USD)': '149.93000000',
#   '3a. low (USD)': '145.77000000',
#   '3b. low (USD)': '145.77000000',
#   '4a. close (USD)': '147.17000000',
#   '4b. close (USD)': '147.17000000',
#   '5. volume': '196329.22503000',
#   '6. market cap (USD)': '196329.22503000'},
#  '2019-12-02': {'1a. open (USD)': '150.72000000',
#   '1b. open (USD)': '150.72000000',
#   '2a. high (USD)': '151.42000000',
#   '2b. high (USD)': '151.42000000',
#   '3a. low (USD)': '146.71000000',
#   '3b. low (USD)': '146.71000000',
#   '4a. close (USD)': '148.65000000',
#   '4b. close (USD)': '148.65000000',
#   '5. volume': '233839.09730000',
#   '6. market cap (USD)': '233839.09730000'},
#  '2019-12-01': {'1a. open (USD)': '151.43000000',
#   '1b. open (USD)': '151.43000000',
#   '2a. high (USD)': '152.49000000',
#   '2b. high (USD)': '152.49000000',
#   '3a. low (USD)': '145.79000000',
#   '3b. low (USD)': '145.79000000',
#   '4a. close (USD)': '150.73000000',
#   '4b. close (USD)': '150.73000000',
#   '5. volume': '344178.14088000',
#   '6. market cap (USD)': '344178.14088000'},
#  '2019-11-30': {'1a. open (USD)': '154.54000000',
#   '1b. open (USD)': '154.54000000',
#   '2a. high (USD)': '155.25000000',
#   '2b. high (USD)': '155.25000000',
#   '3a. low (USD)': '149.70000000',
#   '3b. low (USD)': '149.70000000',
#   '4a. close (USD)': '151.37000000',
#   '4b. close (USD)': '151.37000000',
#   '5. volume': '226863.41299000',
#   '6. market cap (USD)': '226863.41299000'},
#  '2019-11-29': {'1a. open (USD)': '150.69000000',
#   '1b. open (USD)': '150.69000000',
#   '2a. high (USD)': '157.60000000',
#   '2b. high (USD)': '157.60000000',
#   '3a. low (USD)': '150.23000000',
#   '3b. low (USD)': '150.23000000',
#   '4a. close (USD)': '154.57000000',
#   '4b. close (USD)': '154.57000000',
#   '5. volume': '328712.25558000',
#   '6. market cap (USD)': '328712.25558000'},
#  '2019-11-28': {'1a. open (USD)': '152.61000000',
#   '1b. open (USD)': '152.61000000',
#   '2a. high (USD)': '154.63000000',
#   '2b. high (USD)': '154.63000000',
#   '3a. low (USD)': '149.09000000',
#   '3b. low (USD)': '149.09000000',
#   '4a. close (USD)': '150.72000000',
#   '4b. close (USD)': '150.72000000',
#   '5. volume': '317714.56326000',
#   '6. market cap (USD)': '317714.56326000'},
#  '2019-11-27': {'1a. open (USD)': '147.47000000',
#   '1b. open (USD)': '147.47000000',
#   '2a. high (USD)': '155.54000000',
#   '2b. high (USD)': '155.54000000',
#   '3a. low (USD)': '140.84000000',
#   '3b. low (USD)': '140.84000000',
#   '4a. close (USD)': '152.62000000',
#   '4b. close (USD)': '152.62000000',
#   '5. volume': '564796.42840000',
#   '6. market cap (USD)': '564796.42840000'},
#  '2019-11-26': {'1a. open (USD)': '145.81000000',
#   '1b. open (USD)': '145.81000000',
#   '2a. high (USD)': '149.97000000',
#   '2b. high (USD)': '149.97000000',
#   '3a. low (USD)': '143.37000000',
#   '3b. low (USD)': '143.37000000',
#   '4a. close (USD)': '147.47000000',
#   '4b. close (USD)': '147.47000000',
#   '5. volume': '354023.04298000',
#   '6. market cap (USD)': '354023.04298000'},
#  '2019-11-25': {'1a. open (USD)': '139.99000000',
#   '1b. open (USD)': '139.99000000',
#   '2a. high (USD)': '151.50000000',
#   '2b. high (USD)': '151.50000000',
#   '3a. low (USD)': '131.45000000',
#   '3b. low (USD)': '131.45000000',
#   '4a. close (USD)': '145.69000000',
#   '4b. close (USD)': '145.69000000',
#   '5. volume': '749675.41303000',
#   '6. market cap (USD)': '749675.41303000'},
#  '2019-11-24': {'1a. open (USD)': '151.84000000',
#   '1b. open (USD)': '151.84000000',
#   '2a. high (USD)': '152.86000000',
#   '2b. high (USD)': '152.86000000',
#   '3a. low (USD)': '138.62000000',
#   '3b. low (USD)': '138.62000000',
#   '4a. close (USD)': '139.96000000',
#   '4b. close (USD)': '139.96000000',
#   '5. volume': '352319.21558000',
#   '6. market cap (USD)': '352319.21558000'}}

# %%
ETH_openlist = []
ETH_closelist = []
ETH_datelist = []
for date in ETH_dates:
    ETH_datelist.append(date)
    ETH_openlist.append(ETH_dates[date]['1a. open (USD)'])
    ETH_closelist.append(ETH_dates[date]['4a. close (USD)'])

ETH_dict = {'date':ETH_datelist,
    'open':ETH_openlist,
    'close':ETH_closelist}

ETH_dataframe = pd.DataFrame(ETH_dict)
ETH_dataframe
# Out:
#            date           open          close
# 0    2022-08-19  1846.39000000  1819.00000000
# 1    2022-08-18  1834.24000000  1846.39000000
# 2    2022-08-17  1876.67000000  1834.25000000
# 3    2022-08-16  1899.05000000  1876.67000000
# 4    2022-08-15  1935.32000000  1899.06000000
# ..          ...            ...            ...
# 995  2019-11-28   152.61000000   150.72000000
# 996  2019-11-27   147.47000000   152.62000000
# 997  2019-11-26   145.81000000   147.47000000
# 998  2019-11-25   139.99000000   145.69000000
# 999  2019-11-24   151.84000000   139.96000000
#
# [1000 rows x 3 columns]

# %%
BTC_response = requests.get(btc_url).json()
BTC_dates = BTC_response['Time Series (Digital Currency Daily)']
BTC_dates
# Out:
# {'2022-08-19': {'1a. open (USD)': '23191.45000000',
#   '1b. open (USD)': '23191.45000000',
#   '2a. high (USD)': '23208.67000000',
#   '2b. high (USD)': '23208.67000000',
#   '3a. low (USD)': '22877.00000000',
#   '3b. low (USD)': '22877.00000000',
#   '4a. close (USD)': '22925.80000000',
#   '4b. close (USD)': '22925.80000000',
#   '5. volume': '11716.88274000',
#   '6. market cap (USD)': '11716.88274000'},
#  '2022-08-18': {'1a. open (USD)': '23342.66000000',
#   '1b. open (USD)': '23342.66000000',
#   '2a. high (USD)': '23600.00000000',
#   '2b. high (USD)': '23600.00000000',
#   '3a. low (USD)': '23111.04000000',
#   '3b. low (USD)': '23111.04000000',
#   '4a. close (USD)': '23191.20000000',
#   '4b. close (USD)': '23191.20000000',
#   '5. volume': '144185.97011000',
#   '6. market cap (USD)': '144185.97011000'},
#  '2022-08-17': {'1a. open (USD)': '23856.15000000',
#   '1b. open (USD)': '23856.15000000',
#   '2a. high (USD)': '24446.71000000',
#   '2b. high (USD)': '24446.71000000',
#   '3a. low (USD)': '23180.40000000',
#   '3b. low (USD)': '23180.40000000',
#   '4a. close (USD)': '23342.66000000',
#   '4b. close (USD)': '23342.66000000',
#   '5. volume': '210668.68766000',
#   '6. market cap (USD)': '210668.68766000'},
#  '2022-08-16': {'1a. open (USD)': '24093.04000000',
#   '1b. open (USD)': '24093.04000000',
#   '2a. high (USD)': '24247.49000000',
#   '2b. high (USD)': '24247.49000000',
#   '3a. low (USD)': '23671.22000000',
#   '3b. low (USD)': '23671.22000000',
#   '4a. close (USD)': '23854.74000000',
#   '4b. close (USD)': '23854.74000000',
#   '5. volume': '179324.94821000',
#   '6. market cap (USD)': '179324.94821000'},
#  '2022-08-15': {'1a. open (USD)': '24305.25000000',
#   '1b. open (USD)': '24305.25000000',
#   '2a. high (USD)': '25211.32000000',
#   '2b. high (USD)': '25211.32000000',
#   '3a. low (USD)': '23773.22000000',
#   '3b. low (USD)': '23773.22000000',
#   '4a. close (USD)': '24094.82000000',
#   '4b. close (USD)': '24094.82000000',
#   '5. volume': '242539.54758000',
#   '6. market cap (USD)': '242539.54758000'},
#  '2022-08-14': {'1a. open (USD)': '24443.06000000',
#   '1b. open (USD)': '24443.06000000',
#   '2a. high (USD)': '25047.56000000',
#   '2b. high (USD)': '25047.56000000',
#   '3a. low (USD)': '24144.00000000',
#   '3b. low (USD)': '24144.00000000',
#   '4a. close (USD)': '24305.24000000',
#   '4b. close (USD)': '24305.24000000',
#   '5. volume': '151206.14473000',
#   '6. market cap (USD)': '151206.14473000'},
#  '2022-08-13': {'1a. open (USD)': '24401.70000000',
#   '1b. open (USD)': '24401.70000000',
#   '2a. high (USD)': '24888.00000000',
#   '2b. high (USD)': '24888.00000000',
#   '3a. low (USD)': '24291.22000000',
#   '3b. low (USD)': '24291.22000000',
#   '4a. close (USD)': '24441.38000000',
#   '4b. close (USD)': '24441.38000000',
#   '5. volume': '152852.25435000',
#   '6. market cap (USD)': '152852.25435000'},
#  '2022-08-12': {'1a. open (USD)': '23933.09000000',
#   '1b. open (USD)': '23933.09000000',
#   '2a. high (USD)': '24456.50000000',
#   '2b. high (USD)': '24456.50000000',
#   '3a. low (USD)': '23583.00000000',
#   '3b. low (USD)': '23583.00000000',
#   '4a. close (USD)': '24403.68000000',
#   '4b. close (USD)': '24403.68000000',
#   '5. volume': '174207.57040000',
#   '6. market cap (USD)': '174207.57040000'},
#  '2022-08-11': {'1a. open (USD)': '23954.05000000',
#   '1b. open (USD)': '23954.05000000',
#   '2a. high (USD)': '24918.54000000',
#   '2b. high (USD)': '24918.54000000',
#   '3a. low (USD)': '23852.13000000',
#   '3b. low (USD)': '23852.13000000',
#   '4a. close (USD)': '23934.39000000',
#   '4b. close (USD)': '23934.39000000',
#   '5. volume': '249759.79557000',
#   '6. market cap (USD)': '249759.79557000'},
#  '2022-08-10': {'1a. open (USD)': '23151.32000000',
#   '1b. open (USD)': '23151.32000000',
#   '2a. high (USD)': '24226.00000000',
#   '2b. high (USD)': '24226.00000000',
#   '3a. low (USD)': '22664.69000000',
#   '3b. low (USD)': '22664.69000000',
#   '4a. close (USD)': '23954.05000000',
#   '4b. close (USD)': '23954.05000000',
#   '5. volume': '208916.54953000',
#   '6. market cap (USD)': '208916.54953000'},
#  '2022-08-09': {'1a. open (USD)': '23810.98000000',
#   '1b. open (USD)': '23810.98000000',
#   '2a. high (USD)': '23933.25000000',
#   '2b. high (USD)': '23933.25000000',
#   '3a. low (USD)': '22865.00000000',
#   '3b. low (USD)': '22865.00000000',
#   '4a. close (USD)': '23149.95000000',
#   '4b. close (USD)': '23149.95000000',
#   '5. volume': '143182.50858000',
#   '6. market cap (USD)': '143182.50858000'},
#  '2022-08-08': {'1a. open (USD)': '23174.39000000',
#   '1b. open (USD)': '23174.39000000',
#   '2a. high (USD)': '24245.00000000',
#   '2b. high (USD)': '24245.00000000',
#   '3a. low (USD)': '23154.25000000',
#   '3b. low (USD)': '23154.25000000',
#   '4a. close (USD)': '23810.00000000',
#   '4b. close (USD)': '23810.00000000',
#   '5. volume': '170958.44152000',
#   '6. market cap (USD)': '170958.44152000'},
#  '2022-08-07': {'1a. open (USD)': '22954.21000000',
#   '1b. open (USD)': '22954.21000000',
#   '2a. high (USD)': '23402.00000000',
#   '2b. high (USD)': '23402.00000000',
#   '3a. low (USD)': '22844.62000000',
#   '3b. low (USD)': '22844.62000000',
#   '4a. close (USD)': '23174.39000000',
#   '4b. close (USD)': '23174.39000000',
#   '5. volume': '88890.00877000',
#   '6. market cap (USD)': '88890.00877000'},
#  '2022-08-06': {'1a. open (USD)': '23313.56000000',
#   '1b. open (USD)': '23313.56000000',
#   '2a. high (USD)': '23354.36000000',
#   '2b. high (USD)': '23354.36000000',
#   '3a. low (USD)': '22909.52000000',
#   '3b. low (USD)': '22909.52000000',
#   '4a. close (USD)': '22954.21000000',
#   '4b. close (USD)': '22954.21000000',
#   '5. volume': '83911.80307000',
#   '6. market cap (USD)': '83911.80307000'},
#  '2022-08-05': {'1a. open (USD)': '22622.41000000',
#   '1b. open (USD)': '22622.41000000',
#   '2a. high (USD)': '23472.86000000',
#   '2b. high (USD)': '23472.86000000',
#   '3a. low (USD)': '22586.95000000',
#   '3b. low (USD)': '22586.95000000',
#   '4a. close (USD)': '23312.42000000',
#   '4b. close (USD)': '23312.42000000',
#   '5. volume': '175251.69749000',
#   '6. market cap (USD)': '175251.69749000'},
#  '2022-08-04': {'1a. open (USD)': '22816.91000000',
#   '1b. open (USD)': '22816.91000000',
#   '2a. high (USD)': '23223.32000000',
#   '2b. high (USD)': '23223.32000000',
#   '3a. low (USD)': '22400.00000000',
#   '3b. low (USD)': '22400.00000000',
#   '4a. close (USD)': '22622.98000000',
#   '4b. close (USD)': '22622.98000000',
#   '5. volume': '154854.67016000',
#   '6. market cap (USD)': '154854.67016000'},
#  '2022-08-03': {'1a. open (USD)': '22985.93000000',
#   '1b. open (USD)': '22985.93000000',
#   '2a. high (USD)': '23647.68000000',
#   '2b. high (USD)': '23647.68000000',
#   '3a. low (USD)': '22681.22000000',
#   '3b. low (USD)': '22681.22000000',
#   '4a. close (USD)': '22818.37000000',
#   '4b. close (USD)': '22818.37000000',
#   '5. volume': '145948.80995000',
#   '6. market cap (USD)': '145948.80995000'},
#  '2022-08-02': {'1a. open (USD)': '23266.90000000',
#   '1b. open (USD)': '23266.90000000',
#   '2a. high (USD)': '23459.89000000',
#   '2b. high (USD)': '23459.89000000',
#   '3a. low (USD)': '22654.37000000',
#   '3b. low (USD)': '22654.37000000',
#   '4a. close (USD)': '22987.79000000',
#   '4b. close (USD)': '22987.79000000',
#   '5. volume': '158073.28225000',
#   '6. market cap (USD)': '158073.28225000'},
#  '2022-08-01': {'1a. open (USD)': '23296.36000000',
#   '1b. open (USD)': '23296.36000000',
#   '2a. high (USD)': '23509.68000000',
#   '2b. high (USD)': '23509.68000000',
#   '3a. low (USD)': '22850.00000000',
#   '3b. low (USD)': '22850.00000000',
#   '4a. close (USD)': '23268.01000000',
#   '4b. close (USD)': '23268.01000000',
#   '5. volume': '144210.16219000',
#   '6. market cap (USD)': '144210.16219000'},
#  '2022-07-31': {'1a. open (USD)': '23644.64000000',
#   '1b. open (USD)': '23644.64000000',
#   '2a. high (USD)': '24194.82000000',
#   '2b. high (USD)': '24194.82000000',
#   '3a. low (USD)': '23227.31000000',
#   '3b. low (USD)': '23227.31000000',
#   '4a. close (USD)': '23293.32000000',
#   '4b. close (USD)': '23293.32000000',
#   '5. volume': '127743.32483000',
#   '6. market cap (USD)': '127743.32483000'},
#  '2022-07-30': {'1a. open (USD)': '23777.28000000',
#   '1b. open (USD)': '23777.28000000',
#   '2a. high (USD)': '24668.00000000',
#   '2b. high (USD)': '24668.00000000',
#   '3a. low (USD)': '23502.25000000',
#   '3b. low (USD)': '23502.25000000',
#   '4a. close (USD)': '23643.51000000',
#   '4b. close (USD)': '23643.51000000',
#   '5. volume': '151060.13211000',
#   '6. market cap (USD)': '151060.13211000'},
#  '2022-07-29': {'1a. open (USD)': '23845.25000000',
#   '1b. open (USD)': '23845.25000000',
#   '2a. high (USD)': '24442.66000000',
#   '2b. high (USD)': '24442.66000000',
#   '3a. low (USD)': '23414.03000000',
#   '3b. low (USD)': '23414.03000000',
#   '4a. close (USD)': '23773.75000000',
#   '4b. close (USD)': '23773.75000000',
#   '5. volume': '198298.50623000',
#   '6. market cap (USD)': '198298.50623000'},
#  '2022-07-28': {'1a. open (USD)': '22954.31000000',
#   '1b. open (USD)': '22954.31000000',
#   '2a. high (USD)': '24199.72000000',
#   '2b. high (USD)': '24199.72000000',
#   '3a. low (USD)': '22582.13000000',
#   '3b. low (USD)': '22582.13000000',
#   '4a. close (USD)': '23842.93000000',
#   '4b. close (USD)': '23842.93000000',
#   '5. volume': '236029.07410000',
#   '6. market cap (USD)': '236029.07410000'},
#  '2022-07-27': {'1a. open (USD)': '21254.67000000',
#   '1b. open (USD)': '21254.67000000',
#   '2a. high (USD)': '23112.63000000',
#   '2b. high (USD)': '23112.63000000',
#   '3a. low (USD)': '21042.53000000',
#   '3b. low (USD)': '21042.53000000',
#   '4a. close (USD)': '22952.45000000',
#   '4b. close (USD)': '22952.45000000',
#   '5. volume': '210971.19796000',
#   '6. market cap (USD)': '210971.19796000'},
#  '2022-07-26': {'1a. open (USD)': '21310.90000000',
#   '1b. open (USD)': '21310.90000000',
#   '2a. high (USD)': '21347.82000000',
#   '2b. high (USD)': '21347.82000000',
#   '3a. low (USD)': '20706.50000000',
#   '3b. low (USD)': '20706.50000000',
#   '4a. close (USD)': '21254.67000000',
#   '4b. close (USD)': '21254.67000000',
#   '5. volume': '177817.24326000',
#   '6. market cap (USD)': '177817.24326000'},
#  '2022-07-25': {'1a. open (USD)': '22577.13000000',
#   '1b. open (USD)': '22577.13000000',
#   '2a. high (USD)': '22666.00000000',
#   '2b. high (USD)': '22666.00000000',
#   '3a. low (USD)': '21250.00000000',
#   '3b. low (USD)': '21250.00000000',
#   '4a. close (USD)': '21310.90000000',
#   '4b. close (USD)': '21310.90000000',
#   '5. volume': '180344.76643000',
#   '6. market cap (USD)': '180344.76643000'},
#  '2022-07-24': {'1a. open (USD)': '22448.58000000',
#   '1b. open (USD)': '22448.58000000',
#   '2a. high (USD)': '23014.64000000',
#   '2b. high (USD)': '23014.64000000',
#   '3a. low (USD)': '22257.15000000',
#   '3b. low (USD)': '22257.15000000',
#   '4a. close (USD)': '22579.68000000',
#   '4b. close (USD)': '22579.68000000',
#   '5. volume': '115189.67277000',
#   '6. market cap (USD)': '115189.67277000'},
#  '2022-07-23': {'1a. open (USD)': '22684.83000000',
#   '1b. open (USD)': '22684.83000000',
#   '2a. high (USD)': '23000.77000000',
#   '2b. high (USD)': '23000.77000000',
#   '3a. low (USD)': '21934.57000000',
#   '3b. low (USD)': '21934.57000000',
#   '4a. close (USD)': '22451.07000000',
#   '4b. close (USD)': '22451.07000000',
#   '5. volume': '122137.77375000',
#   '6. market cap (USD)': '122137.77375000'},
#  '2022-07-22': {'1a. open (USD)': '23152.19000000',
#   '1b. open (USD)': '23152.19000000',
#   '2a. high (USD)': '23756.49000000',
#   '2b. high (USD)': '23756.49000000',
#   '3a. low (USD)': '22500.00000000',
#   '3b. low (USD)': '22500.00000000',
#   '4a. close (USD)': '22684.83000000',
#   '4b. close (USD)': '22684.83000000',
#   '5. volume': '171598.43966000',
#   '6. market cap (USD)': '171598.43966000'},
#  '2022-07-21': {'1a. open (USD)': '23223.30000000',
#   '1b. open (USD)': '23223.30000000',
#   '2a. high (USD)': '23442.77000000',
#   '2b. high (USD)': '23442.77000000',
#   '3a. low (USD)': '22341.46000000',
#   '3b. low (USD)': '22341.46000000',
#   '4a. close (USD)': '23152.19000000',
#   '4b. close (USD)': '23152.19000000',
#   '5. volume': '184817.68191000',
#   '6. market cap (USD)': '184817.68191000'},
#  '2022-07-20': {'1a. open (USD)': '23398.48000000',
#   '1b. open (USD)': '23398.48000000',
#   '2a. high (USD)': '24276.74000000',
#   '2b. high (USD)': '24276.74000000',
#   '3a. low (USD)': '22906.19000000',
#   '3b. low (USD)': '22906.19000000',
#   '4a. close (USD)': '23223.30000000',
#   '4b. close (USD)': '23223.30000000',
#   '5. volume': '238762.17094000',
#   '6. market cap (USD)': '238762.17094000'},
#  '2022-07-19': {'1a. open (USD)': '22432.58000000',
#   '1b. open (USD)': '22432.58000000',
#   '2a. high (USD)': '23800.00000000',
#   '2b. high (USD)': '23800.00000000',
#   '3a. low (USD)': '21579.54000000',
#   '3b. low (USD)': '21579.54000000',
#   '4a. close (USD)': '23396.62000000',
#   '4b. close (USD)': '23396.62000000',
#   '5. volume': '263770.76574000',
#   '6. market cap (USD)': '263770.76574000'},
#  '2022-07-18': {'1a. open (USD)': '20799.58000000',
#   '1b. open (USD)': '20799.58000000',
#   '2a. high (USD)': '22777.63000000',
#   '2b. high (USD)': '22777.63000000',
#   '3a. low (USD)': '20762.45000000',
#   '3b. low (USD)': '20762.45000000',
#   '4a. close (USD)': '22432.58000000',
#   '4b. close (USD)': '22432.58000000',
#   '5. volume': '239942.73132000',
#   '6. market cap (USD)': '239942.73132000'},
#  '2022-07-17': {'1a. open (USD)': '21195.60000000',
#   '1b. open (USD)': '21195.60000000',
#   '2a. high (USD)': '21684.54000000',
#   '2b. high (USD)': '21684.54000000',
#   '3a. low (USD)': '20750.01000000',
#   '3b. low (USD)': '20750.01000000',
#   '4a. close (USD)': '20798.16000000',
#   '4b. close (USD)': '20798.16000000',
#   '5. volume': '118229.45250000',
#   '6. market cap (USD)': '118229.45250000'},
#  '2022-07-16': {'1a. open (USD)': '20830.04000000',
#   '1b. open (USD)': '20830.04000000',
#   '2a. high (USD)': '21588.94000000',
#   '2b. high (USD)': '21588.94000000',
#   '3a. low (USD)': '20478.61000000',
#   '3b. low (USD)': '20478.61000000',
#   '4a. close (USD)': '21195.60000000',
#   '4b. close (USD)': '21195.60000000',
#   '5. volume': '121011.67393000',
#   '6. market cap (USD)': '121011.67393000'},
#  '2022-07-15': {'1a. open (USD)': '20588.84000000',
#   '1b. open (USD)': '20588.84000000',
#   '2a. high (USD)': '21200.00000000',
#   '2b. high (USD)': '21200.00000000',
#   '3a. low (USD)': '20382.29000000',
#   '3b. low (USD)': '20382.29000000',
#   '4a. close (USD)': '20830.04000000',
#   '4b. close (USD)': '20830.04000000',
#   '5. volume': '143343.30490000',
#   '6. market cap (USD)': '143343.30490000'},
#  '2022-07-14': {'1a. open (USD)': '20234.87000000',
#   '1b. open (USD)': '20234.87000000',
#   '2a. high (USD)': '20900.00000000',
#   '2b. high (USD)': '20900.00000000',
#   '3a. low (USD)': '19616.07000000',
#   '3b. low (USD)': '19616.07000000',
#   '4a. close (USD)': '20588.84000000',
#   '4b. close (USD)': '20588.84000000',
#   '5. volume': '174809.21696000',
#   '6. market cap (USD)': '174809.21696000'},
#  '2022-07-13': {'1a. open (USD)': '19331.28000000',
#   '1b. open (USD)': '19331.28000000',
#   '2a. high (USD)': '20366.61000000',
#   '2b. high (USD)': '20366.61000000',
#   '3a. low (USD)': '18910.94000000',
#   '3b. low (USD)': '18910.94000000',
#   '4a. close (USD)': '20234.87000000',
#   '4b. close (USD)': '20234.87000000',
#   '5. volume': '209250.24888000',
#   '6. market cap (USD)': '209250.24888000'},
#  '2022-07-12': {'1a. open (USD)': '19963.61000000',
#   '1b. open (USD)': '19963.61000000',
#   '2a. high (USD)': '20059.42000000',
#   '2b. high (USD)': '20059.42000000',
#   '3a. low (USD)': '19240.00000000',
#   '3b. low (USD)': '19240.00000000',
#   '4a. close (USD)': '19328.75000000',
#   '4b. close (USD)': '19328.75000000',
#   '5. volume': '139506.45862000',
#   '6. market cap (USD)': '139506.45862000'},
#  '2022-07-11': {'1a. open (USD)': '20861.11000000',
#   '1b. open (USD)': '20861.11000000',
#   '2a. high (USD)': '20868.48000000',
#   '2b. high (USD)': '20868.48000000',
#   '3a. low (USD)': '19875.23000000',
#   '3b. low (USD)': '19875.23000000',
#   '4a. close (USD)': '19963.61000000',
#   '4b. close (USD)': '19963.61000000',
#   '5. volume': '137535.40724000',
#   '6. market cap (USD)': '137535.40724000'},
#  '2022-07-10': {'1a. open (USD)': '21592.15000000',
#   '1b. open (USD)': '21592.15000000',
#   '2a. high (USD)': '21607.65000000',
#   '2b. high (USD)': '21607.65000000',
#   '3a. low (USD)': '20655.00000000',
#   '3b. low (USD)': '20655.00000000',
#   '4a. close (USD)': '20862.47000000',
#   '4b. close (USD)': '20862.47000000',
#   '5. volume': '192188.21556000',
#   '6. market cap (USD)': '192188.21556000'},
#  '2022-07-09': {'1a. open (USD)': '21594.75000000',
#   '1b. open (USD)': '21594.75000000',
#   '2a. high (USD)': '21980.00000000',
#   '2b. high (USD)': '21980.00000000',
#   '3a. low (USD)': '21322.12000000',
#   '3b. low (USD)': '21322.12000000',
#   '4a. close (USD)': '21591.83000000',
#   '4b. close (USD)': '21591.83000000',
#   '5. volume': '178417.84468000',
#   '6. market cap (USD)': '178417.84468000'},
#  '2022-07-08': {'1a. open (USD)': '21624.99000000',
#   '1b. open (USD)': '21624.99000000',
#   '2a. high (USD)': '22527.37000000',
#   '2b. high (USD)': '22527.37000000',
#   '3a. low (USD)': '21189.26000000',
#   '3b. low (USD)': '21189.26000000',
#   '4a. close (USD)': '21594.75000000',
#   '4b. close (USD)': '21594.75000000',
#   '5. volume': '403081.57349000',
#   '6. market cap (USD)': '403081.57349000'},
#  '2022-07-07': {'1a. open (USD)': '20564.51000000',
#   '1b. open (USD)': '20564.51000000',
#   '2a. high (USD)': '21838.10000000',
#   '2b. high (USD)': '21838.10000000',
#   '3a. low (USD)': '20251.68000000',
#   '3b. low (USD)': '20251.68000000',
#   '4a. close (USD)': '21624.98000000',
#   '4b. close (USD)': '21624.98000000',
#   '5. volume': '85014.58261000',
#   '6. market cap (USD)': '85014.58261000'},
#  '2022-07-06': {'1a. open (USD)': '20175.84000000',
#   '1b. open (USD)': '20175.84000000',
#   '2a. high (USD)': '20675.22000000',
#   '2b. high (USD)': '20675.22000000',
#   '3a. low (USD)': '19761.25000000',
#   '3b. low (USD)': '19761.25000000',
#   '4a. close (USD)': '20564.51000000',
#   '4b. close (USD)': '20564.51000000',
#   '5. volume': '82439.58080000',
#   '6. market cap (USD)': '82439.58080000'},
#  '2022-07-05': {'1a. open (USD)': '20236.71000000',
#   '1b. open (USD)': '20236.71000000',
#   '2a. high (USD)': '20750.00000000',
#   '2b. high (USD)': '20750.00000000',
#   '3a. low (USD)': '19304.40000000',
#   '3b. low (USD)': '19304.40000000',
#   '4a. close (USD)': '20175.83000000',
#   '4b. close (USD)': '20175.83000000',
#   '5. volume': '96041.13756000',
#   '6. market cap (USD)': '96041.13756000'},
#  '2022-07-04': {'1a. open (USD)': '19315.83000000',
#   '1b. open (USD)': '19315.83000000',
#   '2a. high (USD)': '20354.01000000',
#   '2b. high (USD)': '20354.01000000',
#   '3a. low (USD)': '19055.31000000',
#   '3b. low (USD)': '19055.31000000',
#   '4a. close (USD)': '20236.71000000',
#   '4b. close (USD)': '20236.71000000',
#   '5. volume': '74814.04601000',
#   '6. market cap (USD)': '74814.04601000'},
#  '2022-07-03': {'1a. open (USD)': '19252.82000000',
#   '1b. open (USD)': '19252.82000000',
#   '2a. high (USD)': '19647.63000000',
#   '2b. high (USD)': '19647.63000000',
#   '3a. low (USD)': '18781.00000000',
#   '3b. low (USD)': '18781.00000000',
#   '4a. close (USD)': '19315.83000000',
#   '4b. close (USD)': '19315.83000000',
#   '5. volume': '51087.46631000',
#   '6. market cap (USD)': '51087.46631000'},
#  '2022-07-02': {'1a. open (USD)': '19279.80000000',
#   '1b. open (USD)': '19279.80000000',
#   '2a. high (USD)': '19467.39000000',
#   '2b. high (USD)': '19467.39000000',
#   '3a. low (USD)': '18977.01000000',
#   '3b. low (USD)': '18977.01000000',
#   '4a. close (USD)': '19252.81000000',
#   '4b. close (USD)': '19252.81000000',
#   '5. volume': '46180.30210000',
#   '6. market cap (USD)': '46180.30210000'},
#  '2022-07-01': {'1a. open (USD)': '19942.21000000',
#   '1b. open (USD)': '19942.21000000',
#   '2a. high (USD)': '20918.35000000',
#   '2b. high (USD)': '20918.35000000',
#   '3a. low (USD)': '18975.00000000',
#   '3b. low (USD)': '18975.00000000',
#   '4a. close (USD)': '19279.80000000',
#   '4b. close (USD)': '19279.80000000',
#   '5. volume': '111844.59494000',
#   '6. market cap (USD)': '111844.59494000'},
#  '2022-06-30': {'1a. open (USD)': '20123.00000000',
#   '1b. open (USD)': '20123.00000000',
#   '2a. high (USD)': '20179.08000000',
#   '2b. high (USD)': '20179.08000000',
#   '3a. low (USD)': '18626.00000000',
#   '3b. low (USD)': '18626.00000000',
#   '4a. close (USD)': '19942.21000000',
#   '4b. close (USD)': '19942.21000000',
#   '5. volume': '93846.64806000',
#   '6. market cap (USD)': '93846.64806000'},
#  '2022-06-29': {'1a. open (USD)': '20281.28000000',
#   '1b. open (USD)': '20281.28000000',
#   '2a. high (USD)': '20432.31000000',
#   '2b. high (USD)': '20432.31000000',
#   '3a. low (USD)': '19854.92000000',
#   '3b. low (USD)': '19854.92000000',
#   '4a. close (USD)': '20123.01000000',
#   '4b. close (USD)': '20123.01000000',
#   '5. volume': '77309.04379000',
#   '6. market cap (USD)': '77309.04379000'},
#  '2022-06-28': {'1a. open (USD)': '20742.57000000',
#   '1b. open (USD)': '20742.57000000',
#   '2a. high (USD)': '21212.10000000',
#   '2b. high (USD)': '21212.10000000',
#   '3a. low (USD)': '20202.01000000',
#   '3b. low (USD)': '20202.01000000',
#   '4a. close (USD)': '20281.29000000',
#   '4b. close (USD)': '20281.29000000',
#   '5. volume': '63801.08320000',
#   '6. market cap (USD)': '63801.08320000'},
#  '2022-06-27': {'1a. open (USD)': '21038.08000000',
#   '1b. open (USD)': '21038.08000000',
#   '2a. high (USD)': '21539.85000000',
#   '2b. high (USD)': '21539.85000000',
#   '3a. low (USD)': '20510.00000000',
#   '3b. low (USD)': '20510.00000000',
#   '4a. close (USD)': '20742.56000000',
#   '4b. close (USD)': '20742.56000000',
#   '5. volume': '64475.00130000',
#   '6. market cap (USD)': '64475.00130000'},
#  '2022-06-26': {'1a. open (USD)': '21491.18000000',
#   '1b. open (USD)': '21491.18000000',
#   '2a. high (USD)': '21888.00000000',
#   '2b. high (USD)': '21888.00000000',
#   '3a. low (USD)': '20964.73000000',
#   '3b. low (USD)': '20964.73000000',
#   '4a. close (USD)': '21038.07000000',
#   '4b. close (USD)': '21038.07000000',
#   '5. volume': '53278.10464000',
#   '6. market cap (USD)': '53278.10464000'},
#  '2022-06-25': {'1a. open (USD)': '21237.68000000',
#   '1b. open (USD)': '21237.68000000',
#   '2a. high (USD)': '21614.50000000',
#   '2b. high (USD)': '21614.50000000',
#   '3a. low (USD)': '20906.62000000',
#   '3b. low (USD)': '20906.62000000',
#   '4a. close (USD)': '21491.19000000',
#   '4b. close (USD)': '21491.19000000',
#   '5. volume': '51431.67794000',
#   '6. market cap (USD)': '51431.67794000'},
#  '2022-06-24': {'1a. open (USD)': '21110.12000000',
#   '1b. open (USD)': '21110.12000000',
#   '2a. high (USD)': '21558.41000000',
#   '2b. high (USD)': '21558.41000000',
#   '3a. low (USD)': '20736.72000000',
#   '3b. low (USD)': '20736.72000000',
#   '4a. close (USD)': '21237.69000000',
#   '4b. close (USD)': '21237.69000000',
#   '5. volume': '77430.36622000',
#   '6. market cap (USD)': '77430.36622000'},
#  '2022-06-23': {'1a. open (USD)': '19988.00000000',
#   '1b. open (USD)': '19988.00000000',
#   '2a. high (USD)': '21233.00000000',
#   '2b. high (USD)': '21233.00000000',
#   '3a. low (USD)': '19890.07000000',
#   '3b. low (USD)': '19890.07000000',
#   '4a. close (USD)': '21110.13000000',
#   '4b. close (USD)': '21110.13000000',
#   '5. volume': '83127.08716000',
#   '6. market cap (USD)': '83127.08716000'},
#  '2022-06-22': {'1a. open (USD)': '20723.51000000',
#   '1b. open (USD)': '20723.51000000',
#   '2a. high (USD)': '20900.00000000',
#   '2b. high (USD)': '20900.00000000',
#   '3a. low (USD)': '19770.51000000',
#   '3b. low (USD)': '19770.51000000',
#   '4a. close (USD)': '19987.99000000',
#   '4b. close (USD)': '19987.99000000',
#   '5. volume': '92133.97938000',
#   '6. market cap (USD)': '92133.97938000'},
#  '2022-06-21': {'1a. open (USD)': '20573.90000000',
#   '1b. open (USD)': '20573.90000000',
#   '2a. high (USD)': '21723.00000000',
#   '2b. high (USD)': '21723.00000000',
#   '3a. low (USD)': '20348.40000000',
#   '3b. low (USD)': '20348.40000000',
#   '4a. close (USD)': '20723.52000000',
#   '4b. close (USD)': '20723.52000000',
#   '5. volume': '104371.07490000',
#   '6. market cap (USD)': '104371.07490000'},
#  '2022-06-20': {'1a. open (USD)': '20574.00000000',
#   '1b. open (USD)': '20574.00000000',
#   '2a. high (USD)': '21090.00000000',
#   '2b. high (USD)': '21090.00000000',
#   '3a. low (USD)': '19637.03000000',
#   '3b. low (USD)': '19637.03000000',
#   '4a. close (USD)': '20573.89000000',
#   '4b. close (USD)': '20573.89000000',
#   '5. volume': '109028.94154000',
#   '6. market cap (USD)': '109028.94154000'},
#  '2022-06-19': {'1a. open (USD)': '18970.79000000',
#   '1b. open (USD)': '18970.79000000',
#   '2a. high (USD)': '20815.95000000',
#   '2b. high (USD)': '20815.95000000',
#   '3a. low (USD)': '17960.41000000',
#   '3b. low (USD)': '17960.41000000',
#   '4a. close (USD)': '20574.00000000',
#   '4b. close (USD)': '20574.00000000',
#   '5. volume': '128320.87595000',
#   '6. market cap (USD)': '128320.87595000'},
#  '2022-06-18': {'1a. open (USD)': '20468.81000000',
#   '1b. open (USD)': '20468.81000000',
#   '2a. high (USD)': '20792.06000000',
#   '2b. high (USD)': '20792.06000000',
#   '3a. low (USD)': '17622.00000000',
#   '3b. low (USD)': '17622.00000000',
#   '4a. close (USD)': '18970.79000000',
#   '4b. close (USD)': '18970.79000000',
#   '5. volume': '196441.65552400',
#   '6. market cap (USD)': '196441.65552400'},
#  '2022-06-17': {'1a. open (USD)': '20400.60000000',
#   '1b. open (USD)': '20400.60000000',
#   '2a. high (USD)': '21365.43000000',
#   '2b. high (USD)': '21365.43000000',
#   '3a. low (USD)': '20246.66000000',
#   '3b. low (USD)': '20246.66000000',
#   '4a. close (USD)': '20468.81000000',
#   '4b. close (USD)': '20468.81000000',
#   '5. volume': '86694.33663000',
#   '6. market cap (USD)': '86694.33663000'},
#  '2022-06-16': {'1a. open (USD)': '22583.72000000',
#   '1b. open (USD)': '22583.72000000',
#   '2a. high (USD)': '22995.73000000',
#   '2b. high (USD)': '22995.73000000',
#   '3a. low (USD)': '20232.00000000',
#   '3b. low (USD)': '20232.00000000',
#   '4a. close (USD)': '20401.31000000',
#   '4b. close (USD)': '20401.31000000',
#   '5. volume': '99673.59429000',
#   '6. market cap (USD)': '99673.59429000'},
#  '2022-06-15': {'1a. open (USD)': '22136.42000000',
#   '1b. open (USD)': '22136.42000000',
#   '2a. high (USD)': '22800.00000000',
#   '2b. high (USD)': '22800.00000000',
#   '3a. low (USD)': '20111.62000000',
#   '3b. low (USD)': '20111.62000000',
#   '4a. close (USD)': '22583.72000000',
#   '4b. close (USD)': '22583.72000000',
#   '5. volume': '200774.49346700',
#   '6. market cap (USD)': '200774.49346700'},
#  '2022-06-14': {'1a. open (USD)': '22485.27000000',
#   '1b. open (USD)': '22485.27000000',
#   '2a. high (USD)': '23362.88000000',
#   '2b. high (USD)': '23362.88000000',
#   '3a. low (USD)': '20846.00000000',
#   '3b. low (USD)': '20846.00000000',
#   '4a. close (USD)': '22136.41000000',
#   '4b. close (USD)': '22136.41000000',
#   '5. volume': '187201.64671000',
#   '6. market cap (USD)': '187201.64671000'},
#  '2022-06-13': {'1a. open (USD)': '26574.53000000',
#   '1b. open (USD)': '26574.53000000',
#   '2a. high (USD)': '26895.84000000',
#   '2b. high (USD)': '26895.84000000',
#   '3a. low (USD)': '21925.77000000',
#   '3b. low (USD)': '21925.77000000',
#   '4a. close (USD)': '22487.41000000',
#   '4b. close (USD)': '22487.41000000',
#   '5. volume': '254611.03496600',
#   '6. market cap (USD)': '254611.03496600'},
#  '2022-06-12': {'1a. open (USD)': '28424.71000000',
#   '1b. open (USD)': '28424.71000000',
#   '2a. high (USD)': '28544.96000000',
#   '2b. high (USD)': '28544.96000000',
#   '3a. low (USD)': '26560.00000000',
#   '3b. low (USD)': '26560.00000000',
#   '4a. close (USD)': '26574.53000000',
#   '4b. close (USD)': '26574.53000000',
#   '5. volume': '92474.59880900',
#   '6. market cap (USD)': '92474.59880900'},
#  '2022-06-11': {'1a. open (USD)': '29091.87000000',
#   '1b. open (USD)': '29091.87000000',
#   '2a. high (USD)': '29440.41000000',
#   '2b. high (USD)': '29440.41000000',
#   '3a. low (USD)': '28099.99000000',
#   '3b. low (USD)': '28099.99000000',
#   '4a. close (USD)': '28424.70000000',
#   '4b. close (USD)': '28424.70000000',
#   '5. volume': '65901.39895000',
#   '6. market cap (USD)': '65901.39895000'},
#  '2022-06-10': {'1a. open (USD)': '30109.93000000',
#   '1b. open (USD)': '30109.93000000',
#   '2a. high (USD)': '30382.80000000',
#   '2b. high (USD)': '30382.80000000',
#   '3a. low (USD)': '28850.00000000',
#   '3b. low (USD)': '28850.00000000',
#   '4a. close (USD)': '29091.88000000',
#   '4b. close (USD)': '29091.88000000',
#   '5. volume': '76204.24980000',
#   '6. market cap (USD)': '76204.24980000'},
#  '2022-06-09': {'1a. open (USD)': '30204.77000000',
#   '1b. open (USD)': '30204.77000000',
#   '2a. high (USD)': '30700.00000000',
#   '2b. high (USD)': '30700.00000000',
#   '3a. low (USD)': '29944.10000000',
#   '3b. low (USD)': '29944.10000000',
#   '4a. close (USD)': '30109.93000000',
#   '4b. close (USD)': '30109.93000000',
#   '5. volume': '46291.18650000',
#   '6. market cap (USD)': '46291.18650000'},
#  '2022-06-08': {'1a. open (USD)': '31125.32000000',
#   '1b. open (USD)': '31125.32000000',
#   '2a. high (USD)': '31327.22000000',
#   '2b. high (USD)': '31327.22000000',
#   '3a. low (USD)': '29843.88000000',
#   '3b. low (USD)': '29843.88000000',
#   '4a. close (USD)': '30204.77000000',
#   '4b. close (USD)': '30204.77000000',
#   '5. volume': '68542.61276000',
#   '6. market cap (USD)': '68542.61276000'},
#  '2022-06-07': {'1a. open (USD)': '31373.10000000',
#   '1b. open (USD)': '31373.10000000',
#   '2a. high (USD)': '31589.60000000',
#   '2b. high (USD)': '31589.60000000',
#   '3a. low (USD)': '29218.96000000',
#   '3b. low (USD)': '29218.96000000',
#   '4a. close (USD)': '31125.33000000',
#   '4b. close (USD)': '31125.33000000',
#   '5. volume': '110674.51658000',
#   '6. market cap (USD)': '110674.51658000'},
#  '2022-06-06': {'1a. open (USD)': '29919.20000000',
#   '1b. open (USD)': '29919.20000000',
#   '2a. high (USD)': '31765.64000000',
#   '2b. high (USD)': '31765.64000000',
#   '3a. low (USD)': '29890.23000000',
#   '3b. low (USD)': '29890.23000000',
#   '4a. close (USD)': '31373.10000000',
#   '4b. close (USD)': '31373.10000000',
#   '5. volume': '68836.92456000',
#   '6. market cap (USD)': '68836.92456000'},
#  '2022-06-05': {'1a. open (USD)': '29864.03000000',
#   '1b. open (USD)': '29864.03000000',
#   '2a. high (USD)': '30189.00000000',
#   '2b. high (USD)': '30189.00000000',
#   '3a. low (USD)': '29531.42000000',
#   '3b. low (USD)': '29531.42000000',
#   '4a. close (USD)': '29919.21000000',
#   '4b. close (USD)': '29919.21000000',
#   '5. volume': '23139.92810000',
#   '6. market cap (USD)': '23139.92810000'},
#  '2022-06-04': {'1a. open (USD)': '29700.21000000',
#   '1b. open (USD)': '29700.21000000',
#   '2a. high (USD)': '29988.88000000',
#   '2b. high (USD)': '29988.88000000',
#   '3a. low (USD)': '29485.00000000',
#   '3b. low (USD)': '29485.00000000',
#   '4a. close (USD)': '29864.04000000',
#   '4b. close (USD)': '29864.04000000',
#   '5. volume': '25617.90113000',
#   '6. market cap (USD)': '25617.90113000'},
#  '2022-06-03': {'1a. open (USD)': '30452.63000000',
#   '1b. open (USD)': '30452.63000000',
#   '2a. high (USD)': '30699.00000000',
#   '2b. high (USD)': '30699.00000000',
#   '3a. low (USD)': '29282.36000000',
#   '3b. low (USD)': '29282.36000000',
#   '4a. close (USD)': '29700.21000000',
#   '4b. close (USD)': '29700.21000000',
#   '5. volume': '54067.44727000',
#   '6. market cap (USD)': '54067.44727000'},
#  '2022-06-02': {'1a. open (USD)': '29805.84000000',
#   '1b. open (USD)': '29805.84000000',
#   '2a. high (USD)': '30689.00000000',
#   '2b. high (USD)': '30689.00000000',
#   '3a. low (USD)': '29594.55000000',
#   '3b. low (USD)': '29594.55000000',
#   '4a. close (USD)': '30452.62000000',
#   '4b. close (USD)': '30452.62000000',
#   '5. volume': '56961.42928000',
#   '6. market cap (USD)': '56961.42928000'},
#  '2022-06-01': {'1a. open (USD)': '31801.05000000',
#   '1b. open (USD)': '31801.05000000',
#   '2a. high (USD)': '31982.97000000',
#   '2b. high (USD)': '31982.97000000',
#   '3a. low (USD)': '29301.00000000',
#   '3b. low (USD)': '29301.00000000',
#   '4a. close (USD)': '29805.83000000',
#   '4b. close (USD)': '29805.83000000',
#   '5. volume': '103395.63382000',
#   '6. market cap (USD)': '103395.63382000'},
#  '2022-05-31': {'1a. open (USD)': '31734.23000000',
#   '1b. open (USD)': '31734.23000000',
#   '2a. high (USD)': '32399.00000000',
#   '2b. high (USD)': '32399.00000000',
#   '3a. low (USD)': '31200.01000000',
#   '3b. low (USD)': '31200.01000000',
#   '4a. close (USD)': '31801.04000000',
#   '4b. close (USD)': '31801.04000000',
#   '5. volume': '62433.11632000',
#   '6. market cap (USD)': '62433.11632000'},
#  '2022-05-30': {'1a. open (USD)': '29468.10000000',
#   '1b. open (USD)': '29468.10000000',
#   '2a. high (USD)': '32222.00000000',
#   '2b. high (USD)': '32222.00000000',
#   '3a. low (USD)': '29299.62000000',
#   '3b. low (USD)': '29299.62000000',
#   '4a. close (USD)': '31734.22000000',
#   '4b. close (USD)': '31734.22000000',
#   '5. volume': '96785.94760000',
#   '6. market cap (USD)': '96785.94760000'},
#  '2022-05-29': {'1a. open (USD)': '29031.33000000',
#   '1b. open (USD)': '29031.33000000',
#   '2a. high (USD)': '29587.78000000',
#   '2b. high (USD)': '29587.78000000',
#   '3a. low (USD)': '28839.21000000',
#   '3b. low (USD)': '28839.21000000',
#   '4a. close (USD)': '29468.10000000',
#   '4b. close (USD)': '29468.10000000',
#   '5. volume': '27567.34764000',
#   '6. market cap (USD)': '27567.34764000'},
#  '2022-05-28': {'1a. open (USD)': '28629.81000000',
#   '1b. open (USD)': '28629.81000000',
#   '2a. high (USD)': '29266.00000000',
#   '2b. high (USD)': '29266.00000000',
#   '3a. low (USD)': '28450.00000000',
#   '3b. low (USD)': '28450.00000000',
#   '4a. close (USD)': '29031.33000000',
#   '4b. close (USD)': '29031.33000000',
#   '5. volume': '34479.35127000',
#   '6. market cap (USD)': '34479.35127000'},
#  '2022-05-27': {'1a. open (USD)': '29201.35000000',
#   '1b. open (USD)': '29201.35000000',
#   '2a. high (USD)': '29397.66000000',
#   '2b. high (USD)': '29397.66000000',
#   '3a. low (USD)': '28282.90000000',
#   '3b. low (USD)': '28282.90000000',
#   '4a. close (USD)': '28629.80000000',
#   '4b. close (USD)': '28629.80000000',
#   '5. volume': '90998.52010000',
#   '6. market cap (USD)': '90998.52010000'},
#  '2022-05-26': {'1a. open (USD)': '29542.14000000',
#   '1b. open (USD)': '29542.14000000',
#   '2a. high (USD)': '29886.64000000',
#   '2b. high (USD)': '29886.64000000',
#   '3a. low (USD)': '28019.56000000',
#   '3b. low (USD)': '28019.56000000',
#   '4a. close (USD)': '29201.35000000',
#   '4b. close (USD)': '29201.35000000',
#   '5. volume': '94581.65463000',
#   '6. market cap (USD)': '94581.65463000'},
#  '2022-05-25': {'1a. open (USD)': '29654.58000000',
#   '1b. open (USD)': '29654.58000000',
#   '2a. high (USD)': '30223.74000000',
#   '2b. high (USD)': '30223.74000000',
#   '3a. low (USD)': '29294.21000000',
#   '3b. low (USD)': '29294.21000000',
#   '4a. close (USD)': '29542.15000000',
#   '4b. close (USD)': '29542.15000000',
#   '5. volume': '59537.38659000',
#   '6. market cap (USD)': '59537.38659000'},
#  '2022-05-24': {'1a. open (USD)': '29109.14000000',
#   '1b. open (USD)': '29109.14000000',
#   '2a. high (USD)': '29845.86000000',
#   '2b. high (USD)': '29845.86000000',
#   '3a. low (USD)': '28669.00000000',
#   '3b. low (USD)': '28669.00000000',
#   '4a. close (USD)': '29654.58000000',
#   '4b. close (USD)': '29654.58000000',
#   '5. volume': '59442.96036000',
#   '6. market cap (USD)': '59442.96036000'},
#  '2022-05-23': {'1a. open (USD)': '30293.93000000',
#   '1b. open (USD)': '30293.93000000',
#   '2a. high (USD)': '30670.51000000',
#   '2b. high (USD)': '30670.51000000',
#   '3a. low (USD)': '28866.35000000',
#   '3b. low (USD)': '28866.35000000',
#   '4a. close (USD)': '29109.15000000',
#   '4b. close (USD)': '29109.15000000',
#   '5. volume': '63901.49932000',
#   '6. market cap (USD)': '63901.49932000'},
#  '2022-05-22': {'1a. open (USD)': '29445.07000000',
#   '1b. open (USD)': '29445.07000000',
#   '2a. high (USD)': '30487.99000000',
#   '2b. high (USD)': '30487.99000000',
#   '3a. low (USD)': '29255.11000000',
#   '3b. low (USD)': '29255.11000000',
#   '4a. close (USD)': '30293.94000000',
#   '4b. close (USD)': '30293.94000000',
#   '5. volume': '36158.98748000',
#   '6. market cap (USD)': '36158.98748000'},
#  '2022-05-21': {'1a. open (USD)': '29201.01000000',
#   '1b. open (USD)': '29201.01000000',
#   '2a. high (USD)': '29656.18000000',
#   '2b. high (USD)': '29656.18000000',
#   '3a. low (USD)': '28947.28000000',
#   '3b. low (USD)': '28947.28000000',
#   '4a. close (USD)': '29445.06000000',
#   '4b. close (USD)': '29445.06000000',
#   '5. volume': '20987.13124000',
#   '6. market cap (USD)': '20987.13124000'},
#  '2022-05-20': {'1a. open (USD)': '30319.22000000',
#   '1b. open (USD)': '30319.22000000',
#   '2a. high (USD)': '30777.33000000',
#   '2b. high (USD)': '30777.33000000',
#   '3a. low (USD)': '28730.00000000',
#   '3b. low (USD)': '28730.00000000',
#   '4a. close (USD)': '29201.01000000',
#   '4b. close (USD)': '29201.01000000',
#   '5. volume': '60517.25325000',
#   '6. market cap (USD)': '60517.25325000'},
#  '2022-05-19': {'1a. open (USD)': '28715.33000000',
#   '1b. open (USD)': '28715.33000000',
#   '2a. high (USD)': '30545.18000000',
#   '2b. high (USD)': '30545.18000000',
#   '3a. low (USD)': '28691.38000000',
#   '3b. low (USD)': '28691.38000000',
#   '4a. close (USD)': '30319.23000000',
#   '4b. close (USD)': '30319.23000000',
#   '5. volume': '67877.36415000',
#   '6. market cap (USD)': '67877.36415000'},
#  '2022-05-18': {'1a. open (USD)': '30444.93000000',
#   '1b. open (USD)': '30444.93000000',
#   '2a. high (USD)': '30709.99000000',
#   '2b. high (USD)': '30709.99000000',
#   '3a. low (USD)': '28654.47000000',
#   '3b. low (USD)': '28654.47000000',
#   '4a. close (USD)': '28715.32000000',
#   '4b. close (USD)': '28715.32000000',
#   '5. volume': '59749.15799000',
#   '6. market cap (USD)': '59749.15799000'},
#  '2022-05-17': {'1a. open (USD)': '29874.01000000',
#   '1b. open (USD)': '29874.01000000',
#   '2a. high (USD)': '30788.37000000',
#   '2b. high (USD)': '30788.37000000',
#   '3a. low (USD)': '29450.38000000',
#   '3b. low (USD)': '29450.38000000',
#   '4a. close (USD)': '30444.93000000',
#   '4b. close (USD)': '30444.93000000',
#   '5. volume': '56724.13307000',
#   '6. market cap (USD)': '56724.13307000'},
#  '2022-05-16': {'1a. open (USD)': '31328.89000000',
#   '1b. open (USD)': '31328.89000000',
#   '2a. high (USD)': '31328.90000000',
#   '2b. high (USD)': '31328.90000000',
#   '3a. low (USD)': '29087.04000000',
#   '3b. low (USD)': '29087.04000000',
#   '4a. close (USD)': '29874.01000000',
#   '4b. close (USD)': '29874.01000000',
#   '5. volume': '73082.19658000',
#   '6. market cap (USD)': '73082.19658000'},
#  '2022-05-15': {'1a. open (USD)': '30086.74000000',
#   '1b. open (USD)': '30086.74000000',
#   '2a. high (USD)': '31460.00000000',
#   '2b. high (USD)': '31460.00000000',
#   '3a. low (USD)': '29480.00000000',
#   '3b. low (USD)': '29480.00000000',
#   '4a. close (USD)': '31328.89000000',
#   '4b. close (USD)': '31328.89000000',
#   '5. volume': '46275.66912000',
#   '6. market cap (USD)': '46275.66912000'},
#  '2022-05-14': {'1a. open (USD)': '29287.05000000',
#   '1b. open (USD)': '29287.05000000',
#   '2a. high (USD)': '30343.27000000',
#   '2b. high (USD)': '30343.27000000',
#   '3a. low (USD)': '28630.00000000',
#   '3b. low (USD)': '28630.00000000',
#   '4a. close (USD)': '30086.74000000',
#   '4b. close (USD)': '30086.74000000',
#   '5. volume': '51095.87863000',
#   '6. market cap (USD)': '51095.87863000'},
#  '2022-05-13': {'1a. open (USD)': '29029.74000000',
#   '1b. open (USD)': '29029.74000000',
#   '2a. high (USD)': '31083.37000000',
#   '2b. high (USD)': '31083.37000000',
#   '3a. low (USD)': '28751.67000000',
#   '3b. low (USD)': '28751.67000000',
#   '4a. close (USD)': '29287.05000000',
#   '4b. close (USD)': '29287.05000000',
#   '5. volume': '97872.36957000',
#   '6. market cap (USD)': '97872.36957000'},
#  '2022-05-12': {'1a. open (USD)': '29103.94000000',
#   '1b. open (USD)': '29103.94000000',
#   '2a. high (USD)': '30243.00000000',
#   '2b. high (USD)': '30243.00000000',
#   '3a. low (USD)': '26700.00000000',
#   '3b. low (USD)': '26700.00000000',
#   '4a. close (USD)': '29029.75000000',
#   '4b. close (USD)': '29029.75000000',
#   '5. volume': '204507.26313800',
#   '6. market cap (USD)': '204507.26313800'},
#  '2022-05-11': {'1a. open (USD)': '31017.11000000',
#   '1b. open (USD)': '31017.11000000',
#   '2a. high (USD)': '32162.59000000',
#   '2b. high (USD)': '32162.59000000',
#   '3a. low (USD)': '27785.00000000',
#   '3b. low (USD)': '27785.00000000',
#   '4a. close (USD)': '29103.94000000',
#   '4b. close (USD)': '29103.94000000',
#   '5. volume': '207063.73927800',
#   '6. market cap (USD)': '207063.73927800'},
#  '2022-05-10': {'1a. open (USD)': '30074.23000000',
#   '1b. open (USD)': '30074.23000000',
#   '2a. high (USD)': '32658.99000000',
#   '2b. high (USD)': '32658.99000000',
#   '3a. low (USD)': '29730.40000000',
#   '3b. low (USD)': '29730.40000000',
#   '4a. close (USD)': '31017.10000000',
#   '4b. close (USD)': '31017.10000000',
#   '5. volume': '165532.00311000',
#   '6. market cap (USD)': '165532.00311000'},
#  '2022-05-09': {'1a. open (USD)': '34038.39000000',
#   '1b. open (USD)': '34038.39000000',
#   '2a. high (USD)': '34243.15000000',
#   '2b. high (USD)': '34243.15000000',
#   '3a. low (USD)': '30033.33000000',
#   '3b. low (USD)': '30033.33000000',
#   '4a. close (USD)': '30076.31000000',
#   '4b. close (USD)': '30076.31000000',
#   '5. volume': '191876.92642800',
#   '6. market cap (USD)': '191876.92642800'},
#  '2022-05-08': {'1a. open (USD)': '35472.40000000',
#   '1b. open (USD)': '35472.40000000',
#   '2a. high (USD)': '35514.22000000',
#   '2b. high (USD)': '35514.22000000',
#   '3a. low (USD)': '33713.95000000',
#   '3b. low (USD)': '33713.95000000',
#   '4a. close (USD)': '34038.40000000',
#   '4b. close (USD)': '34038.40000000',
#   '5. volume': '72445.64344000',
#   '6. market cap (USD)': '72445.64344000'},
#  '2022-05-07': {'1a. open (USD)': '36013.77000000',
#   '1b. open (USD)': '36013.77000000',
#   '2a. high (USD)': '36146.30000000',
#   '2b. high (USD)': '36146.30000000',
#   '3a. low (USD)': '34785.00000000',
#   '3b. low (USD)': '34785.00000000',
#   '4a. close (USD)': '35472.39000000',
#   '4b. close (USD)': '35472.39000000',
#   '5. volume': '34281.70682000',
#   '6. market cap (USD)': '34281.70682000'},
#  '2022-05-06': {'1a. open (USD)': '36552.97000000',
#   '1b. open (USD)': '36552.97000000',
#   '2a. high (USD)': '36675.63000000',
#   '2b. high (USD)': '36675.63000000',
#   '3a. low (USD)': '35258.00000000',
#   '3b. low (USD)': '35258.00000000',
#   '4a. close (USD)': '36013.77000000',
#   '4b. close (USD)': '36013.77000000',
#   '5. volume': '68437.80187000',
#   '6. market cap (USD)': '68437.80187000'},
#  '2022-05-05': {'1a. open (USD)': '39690.00000000',
#   '1b. open (USD)': '39690.00000000',
#   '2a. high (USD)': '39845.51000000',
#   '2b. high (USD)': '39845.51000000',
#   '3a. low (USD)': '35571.90000000',
#   '3b. low (USD)': '35571.90000000',
#   '4a. close (USD)': '36552.97000000',
#   '4b. close (USD)': '36552.97000000',
#   '5. volume': '88722.43355000',
#   '6. market cap (USD)': '88722.43355000'},
#  '2022-05-04': {'1a. open (USD)': '37728.95000000',
#   '1b. open (USD)': '37728.95000000',
#   '2a. high (USD)': '40023.77000000',
#   '2b. high (USD)': '40023.77000000',
#   '3a. low (USD)': '37670.00000000',
#   '3b. low (USD)': '37670.00000000',
#   '4a. close (USD)': '39690.00000000',
#   '4b. close (USD)': '39690.00000000',
#   '5. volume': '62574.61736000',
#   '6. market cap (USD)': '62574.61736000'},
#  '2022-05-03': {'1a. open (USD)': '38525.16000000',
#   '1b. open (USD)': '38525.16000000',
#   '2a. high (USD)': '38651.51000000',
#   '2b. high (USD)': '38651.51000000',
#   '3a. low (USD)': '37517.80000000',
#   '3b. low (USD)': '37517.80000000',
#   '4a. close (USD)': '37728.95000000',
#   '4b. close (USD)': '37728.95000000',
#   '5. volume': '40316.45358000',
#   '6. market cap (USD)': '40316.45358000'},
#  '2022-05-02': {'1a. open (USD)': '38468.35000000',
#   '1b. open (USD)': '38468.35000000',
#   '2a. high (USD)': '39167.34000000',
#   '2b. high (USD)': '39167.34000000',
#   '3a. low (USD)': '38052.00000000',
#   '3b. low (USD)': '38052.00000000',
#   '4a. close (USD)': '38525.16000000',
#   '4b. close (USD)': '38525.16000000',
#   '5. volume': '53200.92628000',
#   '6. market cap (USD)': '53200.92628000'},
#  '2022-05-01': {'1a. open (USD)': '37630.80000000',
#   '1b. open (USD)': '37630.80000000',
#   '2a. high (USD)': '38675.00000000',
#   '2b. high (USD)': '38675.00000000',
#   '3a. low (USD)': '37386.38000000',
#   '3b. low (USD)': '37386.38000000',
#   '4a. close (USD)': '38468.35000000',
#   '4b. close (USD)': '38468.35000000',
#   '5. volume': '38812.24104000',
#   '6. market cap (USD)': '38812.24104000'},
#  '2022-04-30': {'1a. open (USD)': '38596.11000000',
#   '1b. open (USD)': '38596.11000000',
#   '2a. high (USD)': '38795.38000000',
#   '2b. high (USD)': '38795.38000000',
#   '3a. low (USD)': '37578.20000000',
#   '3b. low (USD)': '37578.20000000',
#   '4a. close (USD)': '37630.80000000',
#   '4b. close (USD)': '37630.80000000',
#   '5. volume': '35321.18989000',
#   '6. market cap (USD)': '35321.18989000'},
#  '2022-04-29': {'1a. open (USD)': '39742.06000000',
#   '1b. open (USD)': '39742.06000000',
#   '2a. high (USD)': '39925.25000000',
#   '2b. high (USD)': '39925.25000000',
#   '3a. low (USD)': '38175.00000000',
#   '3b. low (USD)': '38175.00000000',
#   '4a. close (USD)': '38596.11000000',
#   '4b. close (USD)': '38596.11000000',
#   '5. volume': '51453.65715000',
#   '6. market cap (USD)': '51453.65715000'},
#  '2022-04-28': {'1a. open (USD)': '39235.72000000',
#   '1b. open (USD)': '39235.72000000',
#   '2a. high (USD)': '40372.63000000',
#   '2b. high (USD)': '40372.63000000',
#   '3a. low (USD)': '38881.43000000',
#   '3b. low (USD)': '38881.43000000',
#   '4a. close (USD)': '39742.07000000',
#   '4b. close (USD)': '39742.07000000',
#   '5. volume': '56086.67150000',
#   '6. market cap (USD)': '56086.67150000'},
#  '2022-04-27': {'1a. open (USD)': '38112.64000000',
#   '1b. open (USD)': '38112.64000000',
#   '2a. high (USD)': '39474.72000000',
#   '2b. high (USD)': '39474.72000000',
#   '3a. low (USD)': '37881.31000000',
#   '3b. low (USD)': '37881.31000000',
#   '4a. close (USD)': '39235.72000000',
#   '4b. close (USD)': '39235.72000000',
#   '5. volume': '57083.12272000',
#   '6. market cap (USD)': '57083.12272000'},
#  '2022-04-26': {'1a. open (USD)': '40426.08000000',
#   '1b. open (USD)': '40426.08000000',
#   '2a. high (USD)': '40797.31000000',
#   '2b. high (USD)': '40797.31000000',
#   '3a. low (USD)': '37702.26000000',
#   '3b. low (USD)': '37702.26000000',
#   '4a. close (USD)': '38112.65000000',
#   '4b. close (USD)': '38112.65000000',
#   '5. volume': '66650.25800000',
#   '6. market cap (USD)': '66650.25800000'},
#  '2022-04-25': {'1a. open (USD)': '39450.12000000',
#   '1b. open (USD)': '39450.12000000',
#   '2a. high (USD)': '40616.00000000',
#   '2b. high (USD)': '40616.00000000',
#   '3a. low (USD)': '38200.00000000',
#   '3b. low (USD)': '38200.00000000',
#   '4a. close (USD)': '40426.08000000',
#   '4b. close (USD)': '40426.08000000',
#   '5. volume': '63037.12784000',
#   '6. market cap (USD)': '63037.12784000'},
#  '2022-04-24': {'1a. open (USD)': '39441.61000000',
#   '1b. open (USD)': '39441.61000000',
#   '2a. high (USD)': '39940.00000000',
#   '2b. high (USD)': '39940.00000000',
#   '3a. low (USD)': '38929.62000000',
#   '3b. low (USD)': '38929.62000000',
#   '4a. close (USD)': '39450.13000000',
#   '4b. close (USD)': '39450.13000000',
#   '5. volume': '26703.61186000',
#   '6. market cap (USD)': '26703.61186000'},
#  '2022-04-23': {'1a. open (USD)': '39709.19000000',
#   '1b. open (USD)': '39709.19000000',
#   '2a. high (USD)': '39980.00000000',
#   '2b. high (USD)': '39980.00000000',
#   '3a. low (USD)': '39285.00000000',
#   '3b. low (USD)': '39285.00000000',
#   '4a. close (USD)': '39441.60000000',
#   '4b. close (USD)': '39441.60000000',
#   '5. volume': '20291.42375000',
#   '6. market cap (USD)': '20291.42375000'},
#  '2022-04-22': {'1a. open (USD)': '40480.01000000',
#   '1b. open (USD)': '40480.01000000',
#   '2a. high (USD)': '40795.06000000',
#   '2b. high (USD)': '40795.06000000',
#   '3a. low (USD)': '39177.00000000',
#   '3b. low (USD)': '39177.00000000',
#   '4a. close (USD)': '39709.18000000',
#   '4b. close (USD)': '39709.18000000',
#   '5. volume': '46664.01960000',
#   '6. market cap (USD)': '46664.01960000'},
#  '2022-04-21': {'1a. open (USD)': '41358.19000000',
#   '1b. open (USD)': '41358.19000000',
#   '2a. high (USD)': '42976.00000000',
#   '2b. high (USD)': '42976.00000000',
#   '3a. low (USD)': '39751.00000000',
#   '3b. low (USD)': '39751.00000000',
#   '4a. close (USD)': '40480.01000000',
#   '4b. close (USD)': '40480.01000000',
#   '5. volume': '59316.27657000',
#   '6. market cap (USD)': '59316.27657000'},
#  '2022-04-20': {'1a. open (USD)': '41493.19000000',
#   '1b. open (USD)': '41493.19000000',
# ...
#   '4b. close (USD)': '7354.11000000',
#   '5. volume': '29987.97497700',
#   '6. market cap (USD)': '29987.97497700'},
#  '2020-01-03': {'1a. open (USD)': '6965.49000000',
#   '1b. open (USD)': '6965.49000000',
#   '2a. high (USD)': '7405.00000000',
#   '2b. high (USD)': '7405.00000000',
#   '3a. low (USD)': '6871.04000000',
#   '3b. low (USD)': '6871.04000000',
#   '4a. close (USD)': '7344.96000000',
#   '4b. close (USD)': '7344.96000000',
#   '5. volume': '68428.50045100',
#   '6. market cap (USD)': '68428.50045100'},
#  '2020-01-02': {'1a. open (USD)': '7200.77000000',
#   '1b. open (USD)': '7200.77000000',
#   '2a. high (USD)': '7212.50000000',
#   '2b. high (USD)': '7212.50000000',
#   '3a. low (USD)': '6924.74000000',
#   '3b. low (USD)': '6924.74000000',
#   '4a. close (USD)': '6965.71000000',
#   '4b. close (USD)': '6965.71000000',
#   '5. volume': '31951.48393200',
#   '6. market cap (USD)': '31951.48393200'},
#  '2020-01-01': {'1a. open (USD)': '7195.24000000',
#   '1b. open (USD)': '7195.24000000',
#   '2a. high (USD)': '7255.00000000',
#   '2b. high (USD)': '7255.00000000',
#   '3a. low (USD)': '7175.15000000',
#   '3b. low (USD)': '7175.15000000',
#   '4a. close (USD)': '7200.85000000',
#   '4b. close (USD)': '7200.85000000',
#   '5. volume': '16792.38816500',
#   '6. market cap (USD)': '16792.38816500'},
#  '2019-12-31': {'1a. open (USD)': '7246.00000000',
#   '1b. open (USD)': '7246.00000000',
#   '2a. high (USD)': '7320.00000000',
#   '2b. high (USD)': '7320.00000000',
#   '3a. low (USD)': '7145.01000000',
#   '3b. low (USD)': '7145.01000000',
#   '4a. close (USD)': '7195.23000000',
#   '4b. close (USD)': '7195.23000000',
#   '5. volume': '25954.45353300',
#   '6. market cap (USD)': '25954.45353300'},
#  '2019-12-30': {'1a. open (USD)': '7388.43000000',
#   '1b. open (USD)': '7388.43000000',
#   '2a. high (USD)': '7408.24000000',
#   '2b. high (USD)': '7408.24000000',
#   '3a. low (USD)': '7220.00000000',
#   '3b. low (USD)': '7220.00000000',
#   '4a. close (USD)': '7246.00000000',
#   '4b. close (USD)': '7246.00000000',
#   '5. volume': '29605.91178200',
#   '6. market cap (USD)': '29605.91178200'},
#  '2019-12-29': {'1a. open (USD)': '7315.36000000',
#   '1b. open (USD)': '7315.36000000',
#   '2a. high (USD)': '7528.45000000',
#   '2b. high (USD)': '7528.45000000',
#   '3a. low (USD)': '7288.00000000',
#   '3b. low (USD)': '7288.00000000',
#   '4a. close (USD)': '7388.24000000',
#   '4b. close (USD)': '7388.24000000',
#   '5. volume': '31387.10608500',
#   '6. market cap (USD)': '31387.10608500'},
#  '2019-12-28': {'1a. open (USD)': '7254.77000000',
#   '1b. open (USD)': '7254.77000000',
#   '2a. high (USD)': '7365.01000000',
#   '2b. high (USD)': '7365.01000000',
#   '3a. low (USD)': '7238.67000000',
#   '3b. low (USD)': '7238.67000000',
#   '4a. close (USD)': '7316.14000000',
#   '4b. close (USD)': '7316.14000000',
#   '5. volume': '26848.98219900',
#   '6. market cap (USD)': '26848.98219900'},
#  '2019-12-27': {'1a. open (USD)': '7202.00000000',
#   '1b. open (USD)': '7202.00000000',
#   '2a. high (USD)': '7275.86000000',
#   '2b. high (USD)': '7275.86000000',
#   '3a. low (USD)': '7076.42000000',
#   '3b. low (USD)': '7076.42000000',
#   '4a. close (USD)': '7254.74000000',
#   '4b. close (USD)': '7254.74000000',
#   '5. volume': '33642.70186100',
#   '6. market cap (USD)': '33642.70186100'},
#  '2019-12-26': {'1a. open (USD)': '7205.01000000',
#   '1b. open (USD)': '7205.01000000',
#   '2a. high (USD)': '7435.00000000',
#   '2b. high (USD)': '7435.00000000',
#   '3a. low (USD)': '7157.12000000',
#   '3b. low (USD)': '7157.12000000',
#   '4a. close (USD)': '7202.00000000',
#   '4b. close (USD)': '7202.00000000',
#   '5. volume': '36259.76107600',
#   '6. market cap (USD)': '36259.76107600'},
#  '2019-12-25': {'1a. open (USD)': '7255.77000000',
#   '1b. open (USD)': '7255.77000000',
#   '2a. high (USD)': '7271.77000000',
#   '2b. high (USD)': '7271.77000000',
#   '3a. low (USD)': '7128.86000000',
#   '3b. low (USD)': '7128.86000000',
#   '4a. close (USD)': '7204.63000000',
#   '4b. close (USD)': '7204.63000000',
#   '5. volume': '27492.04432300',
#   '6. market cap (USD)': '27492.04432300'},
#  '2019-12-24': {'1a. open (USD)': '7317.30000000',
#   '1b. open (USD)': '7317.30000000',
#   '2a. high (USD)': '7436.68000000',
#   '2b. high (USD)': '7436.68000000',
#   '3a. low (USD)': '7157.04000000',
#   '3b. low (USD)': '7157.04000000',
#   '4a. close (USD)': '7255.77000000',
#   '4b. close (USD)': '7255.77000000',
#   '5. volume': '43629.49418800',
#   '6. market cap (USD)': '43629.49418800'},
#  '2019-12-23': {'1a. open (USD)': '7500.71000000',
#   '1b. open (USD)': '7500.71000000',
#   '2a. high (USD)': '7695.38000000',
#   '2b. high (USD)': '7695.38000000',
#   '3a. low (USD)': '7265.84000000',
#   '3b. low (USD)': '7265.84000000',
#   '4a. close (USD)': '7317.09000000',
#   '4b. close (USD)': '7317.09000000',
#   '5. volume': '68051.99720300',
#   '6. market cap (USD)': '68051.99720300'},
#  '2019-12-22': {'1a. open (USD)': '7131.59000000',
#   '1b. open (USD)': '7131.59000000',
#   '2a. high (USD)': '7518.54000000',
#   '2b. high (USD)': '7518.54000000',
#   '3a. low (USD)': '7122.47000000',
#   '3b. low (USD)': '7122.47000000',
#   '4a. close (USD)': '7501.44000000',
#   '4b. close (USD)': '7501.44000000',
#   '5. volume': '39137.45515000',
#   '6. market cap (USD)': '39137.45515000'},
#  '2019-12-21': {'1a. open (USD)': '7188.01000000',
#   '1b. open (USD)': '7188.01000000',
#   '2a. high (USD)': '7190.58000000',
#   '2b. high (USD)': '7190.58000000',
#   '3a. low (USD)': '7105.00000000',
#   '3b. low (USD)': '7105.00000000',
#   '4a. close (USD)': '7132.75000000',
#   '4b. close (USD)': '7132.75000000',
#   '5. volume': '19467.17402800',
#   '6. market cap (USD)': '19467.17402800'},
#  '2019-12-20': {'1a. open (USD)': '7151.31000000',
#   '1b. open (USD)': '7151.31000000',
#   '2a. high (USD)': '7220.00000000',
#   '2b. high (USD)': '7220.00000000',
#   '3a. low (USD)': '7079.50000000',
#   '3b. low (USD)': '7079.50000000',
#   '4a. close (USD)': '7187.83000000',
#   '4b. close (USD)': '7187.83000000',
#   '5. volume': '32132.06920500',
#   '6. market cap (USD)': '32132.06920500'},
#  '2019-12-19': {'1a. open (USD)': '7277.83000000',
#   '1b. open (USD)': '7277.83000000',
#   '2a. high (USD)': '7380.00000000',
#   '2b. high (USD)': '7380.00000000',
#   '3a. low (USD)': '7038.31000000',
#   '3b. low (USD)': '7038.31000000',
#   '4a. close (USD)': '7150.30000000',
#   '4b. close (USD)': '7150.30000000',
#   '5. volume': '55509.04907500',
#   '6. market cap (USD)': '55509.04907500'},
#  '2019-12-18': {'1a. open (USD)': '6623.84000000',
#   '1b. open (USD)': '6623.84000000',
#   '2a. high (USD)': '7440.00000000',
#   '2b. high (USD)': '7440.00000000',
#   '3a. low (USD)': '6435.00000000',
#   '3b. low (USD)': '6435.00000000',
#   '4a. close (USD)': '7277.83000000',
#   '4b. close (USD)': '7277.83000000',
#   '5. volume': '95636.65125100',
#   '6. market cap (USD)': '95636.65125100'},
#  '2019-12-17': {'1a. open (USD)': '6891.44000000',
#   '1b. open (USD)': '6891.44000000',
#   '2a. high (USD)': '6942.21000000',
#   '2b. high (USD)': '6942.21000000',
#   '3a. low (USD)': '6560.00000000',
#   '3b. low (USD)': '6560.00000000',
#   '4a. close (USD)': '6623.82000000',
#   '4b. close (USD)': '6623.82000000',
#   '5. volume': '53865.06992900',
#   '6. market cap (USD)': '53865.06992900'},
#  '2019-12-16': {'1a. open (USD)': '7119.60000000',
#   '1b. open (USD)': '7119.60000000',
#   '2a. high (USD)': '7150.00000000',
#   '2b. high (USD)': '7150.00000000',
#   '3a. low (USD)': '6836.00000000',
#   '3b. low (USD)': '6836.00000000',
#   '4a. close (USD)': '6891.72000000',
#   '4b. close (USD)': '6891.72000000',
#   '5. volume': '43863.99305900',
#   '6. market cap (USD)': '43863.99305900'},
#  '2019-12-15': {'1a. open (USD)': '7064.14000000',
#   '1b. open (USD)': '7064.14000000',
#   '2a. high (USD)': '7200.30000000',
#   '2b. high (USD)': '7200.30000000',
#   '3a. low (USD)': '7008.35000000',
#   '3b. low (USD)': '7008.35000000',
#   '4a. close (USD)': '7118.59000000',
#   '4b. close (USD)': '7118.59000000',
#   '5. volume': '26395.77813700',
#   '6. market cap (USD)': '26395.77813700'},
#  '2019-12-14': {'1a. open (USD)': '7257.37000000',
#   '1b. open (USD)': '7257.37000000',
#   '2a. high (USD)': '7271.77000000',
#   '2b. high (USD)': '7271.77000000',
#   '3a. low (USD)': '7012.00000000',
#   '3b. low (USD)': '7012.00000000',
#   '4a. close (USD)': '7064.05000000',
#   '4b. close (USD)': '7064.05000000',
#   '5. volume': '29561.98596700',
#   '6. market cap (USD)': '29561.98596700'},
#  '2019-12-13': {'1a. open (USD)': '7197.76000000',
#   '1b. open (USD)': '7197.76000000',
#   '2a. high (USD)': '7309.05000000',
#   '2b. high (USD)': '7309.05000000',
#   '3a. low (USD)': '7190.76000000',
#   '3b. low (USD)': '7190.76000000',
#   '4a. close (USD)': '7258.48000000',
#   '4b. close (USD)': '7258.48000000',
#   '5. volume': '27609.87379500',
#   '6. market cap (USD)': '27609.87379500'},
#  '2019-12-12': {'1a. open (USD)': '7210.00000000',
#   '1b. open (USD)': '7210.00000000',
#   '2a. high (USD)': '7295.00000000',
#   '2b. high (USD)': '7295.00000000',
#   '3a. low (USD)': '7080.30000000',
#   '3b. low (USD)': '7080.30000000',
#   '4a. close (USD)': '7198.08000000',
#   '4b. close (USD)': '7198.08000000',
#   '5. volume': '42288.60093200',
#   '6. market cap (USD)': '42288.60093200'},
#  '2019-12-11': {'1a. open (USD)': '7224.15000000',
#   '1b. open (USD)': '7224.15000000',
#   '2a. high (USD)': '7275.50000000',
#   '2b. high (USD)': '7275.50000000',
#   '3a. low (USD)': '7125.66000000',
#   '3b. low (USD)': '7125.66000000',
#   '4a. close (USD)': '7210.00000000',
#   '4b. close (USD)': '7210.00000000',
#   '5. volume': '30093.09194400',
#   '6. market cap (USD)': '30093.09194400'},
#  '2019-12-10': {'1a. open (USD)': '7338.64000000',
#   '1b. open (USD)': '7338.64000000',
#   '2a. high (USD)': '7407.60000000',
#   '2b. high (USD)': '7407.60000000',
#   '3a. low (USD)': '7157.10000000',
#   '3b. low (USD)': '7157.10000000',
#   '4a. close (USD)': '7224.13000000',
#   '4b. close (USD)': '7224.13000000',
#   '5. volume': '49723.76214000',
#   '6. market cap (USD)': '49723.76214000'},
#  '2019-12-09': {'1a. open (USD)': '7510.11000000',
#   '1b. open (USD)': '7510.11000000',
#   '2a. high (USD)': '7650.00000000',
#   '2b. high (USD)': '7650.00000000',
#   '3a. low (USD)': '7273.00000000',
#   '3b. low (USD)': '7273.00000000',
#   '4a. close (USD)': '7338.64000000',
#   '4b. close (USD)': '7338.64000000',
#   '5. volume': '46621.88749300',
#   '6. market cap (USD)': '46621.88749300'},
#  '2019-12-08': {'1a. open (USD)': '7487.31000000',
#   '1b. open (USD)': '7487.31000000',
#   '2a. high (USD)': '7564.00000000',
#   '2b. high (USD)': '7564.00000000',
#   '3a. low (USD)': '7374.86000000',
#   '3b. low (USD)': '7374.86000000',
#   '4a. close (USD)': '7510.11000000',
#   '4b. close (USD)': '7510.11000000',
#   '5. volume': '29856.89763100',
#   '6. market cap (USD)': '29856.89763100'},
#  '2019-12-07': {'1a. open (USD)': '7527.80000000',
#   '1b. open (USD)': '7527.80000000',
#   '2a. high (USD)': '7619.62000000',
#   '2b. high (USD)': '7619.62000000',
#   '3a. low (USD)': '7470.16000000',
#   '3b. low (USD)': '7470.16000000',
#   '4a. close (USD)': '7488.21000000',
#   '4b. close (USD)': '7488.21000000',
#   '5. volume': '31498.68417300',
#   '6. market cap (USD)': '31498.68417300'},
#  '2019-12-06': {'1a. open (USD)': '7389.00000000',
#   '1b. open (USD)': '7389.00000000',
#   '2a. high (USD)': '7590.03000000',
#   '2b. high (USD)': '7590.03000000',
#   '3a. low (USD)': '7305.00000000',
#   '3b. low (USD)': '7305.00000000',
#   '4a. close (USD)': '7527.47000000',
#   '4b. close (USD)': '7527.47000000',
#   '5. volume': '48189.08794400',
#   '6. market cap (USD)': '48189.08794400'},
#  '2019-12-05': {'1a. open (USD)': '7194.59000000',
#   '1b. open (USD)': '7194.59000000',
#   '2a. high (USD)': '7485.00000000',
#   '2b. high (USD)': '7485.00000000',
#   '3a. low (USD)': '7150.00000000',
#   '3b. low (USD)': '7150.00000000',
#   '4a. close (USD)': '7389.00000000',
#   '4b. close (USD)': '7389.00000000',
#   '5. volume': '59306.67885500',
#   '6. market cap (USD)': '59306.67885500'},
#  '2019-12-04': {'1a. open (USD)': '7292.71000000',
#   '1b. open (USD)': '7292.71000000',
#   '2a. high (USD)': '7750.00000000',
#   '2b. high (USD)': '7750.00000000',
#   '3a. low (USD)': '7067.00000000',
#   '3b. low (USD)': '7067.00000000',
#   '4a. close (USD)': '7194.32000000',
#   '4b. close (USD)': '7194.32000000',
#   '5. volume': '83153.70158600',
#   '6. market cap (USD)': '83153.70158600'},
#  '2019-12-03': {'1a. open (USD)': '7294.42000000',
#   '1b. open (USD)': '7294.42000000',
#   '2a. high (USD)': '7400.00000000',
#   '2b. high (USD)': '7400.00000000',
#   '3a. low (USD)': '7241.35000000',
#   '3b. low (USD)': '7241.35000000',
#   '4a. close (USD)': '7292.71000000',
#   '4b. close (USD)': '7292.71000000',
#   '5. volume': '33149.47748700',
#   '6. market cap (USD)': '33149.47748700'},
#  '2019-12-02': {'1a. open (USD)': '7391.50000000',
#   '1b. open (USD)': '7391.50000000',
#   '2a. high (USD)': '7420.56000000',
#   '2b. high (USD)': '7420.56000000',
#   '3a. low (USD)': '7151.10000000',
#   '3b. low (USD)': '7151.10000000',
#   '4a. close (USD)': '7294.28000000',
#   '4b. close (USD)': '7294.28000000',
#   '5. volume': '46330.25604000',
#   '6. market cap (USD)': '46330.25604000'},
#  '2019-12-01': {'1a. open (USD)': '7540.63000000',
#   '1b. open (USD)': '7540.63000000',
#   '2a. high (USD)': '7541.85000000',
#   '2b. high (USD)': '7541.85000000',
#   '3a. low (USD)': '7210.00000000',
#   '3b. low (USD)': '7210.00000000',
#   '4a. close (USD)': '7390.89000000',
#   '4b. close (USD)': '7390.89000000',
#   '5. volume': '60769.34231300',
#   '6. market cap (USD)': '60769.34231300'},
#  '2019-11-30': {'1a. open (USD)': '7740.99000000',
#   '1b. open (USD)': '7740.99000000',
#   '2a. high (USD)': '7810.00000000',
#   '2b. high (USD)': '7810.00000000',
#   '3a. low (USD)': '7441.00000000',
#   '3b. low (USD)': '7441.00000000',
#   '4a. close (USD)': '7541.89000000',
#   '4b. close (USD)': '7541.89000000',
#   '5. volume': '46989.43361900',
#   '6. market cap (USD)': '46989.43361900'},
#  '2019-11-29': {'1a. open (USD)': '7418.52000000',
#   '1b. open (USD)': '7418.52000000',
#   '2a. high (USD)': '7850.00000000',
#   '2b. high (USD)': '7850.00000000',
#   '3a. low (USD)': '7362.30000000',
#   '3b. low (USD)': '7362.30000000',
#   '4a. close (USD)': '7739.68000000',
#   '4b. close (USD)': '7739.68000000',
#   '5. volume': '60745.30087300',
#   '6. market cap (USD)': '60745.30087300'},
#  '2019-11-28': {'1a. open (USD)': '7507.90000000',
#   '1b. open (USD)': '7507.90000000',
#   '2a. high (USD)': '7643.00000000',
#   '2b. high (USD)': '7643.00000000',
#   '3a. low (USD)': '7360.00000000',
#   '3b. low (USD)': '7360.00000000',
#   '4a. close (USD)': '7419.49000000',
#   '4b. close (USD)': '7419.49000000',
#   '5. volume': '56933.98110900',
#   '6. market cap (USD)': '56933.98110900'},
#  '2019-11-27': {'1a. open (USD)': '7154.75000000',
#   '1b. open (USD)': '7154.75000000',
#   '2a. high (USD)': '7655.00000000',
#   '2b. high (USD)': '7655.00000000',
#   '3a. low (USD)': '6840.00000000',
#   '3b. low (USD)': '6840.00000000',
#   '4a. close (USD)': '7508.52000000',
#   '4b. close (USD)': '7508.52000000',
#   '5. volume': '92452.87349000',
#   '6. market cap (USD)': '92452.87349000'},
#  '2019-11-26': {'1a. open (USD)': '7109.99000000',
#   '1b. open (USD)': '7109.99000000',
#   '2a. high (USD)': '7340.00000000',
#   '2b. high (USD)': '7340.00000000',
#   '3a. low (USD)': '7017.48000000',
#   '3b. low (USD)': '7017.48000000',
#   '4a. close (USD)': '7156.14000000',
#   '4b. close (USD)': '7156.14000000',
#   '5. volume': '65722.39769000',
#   '6. market cap (USD)': '65722.39769000'},
#  '2019-11-25': {'1a. open (USD)': '6900.23000000',
#   '1b. open (USD)': '6900.23000000',
#   '2a. high (USD)': '7377.69000000',
#   '2b. high (USD)': '7377.69000000',
#   '3a. low (USD)': '6515.00000000',
#   '3b. low (USD)': '6515.00000000',
#   '4a. close (USD)': '7109.57000000',
#   '4b. close (USD)': '7109.57000000',
#   '5. volume': '119645.73519700',
#   '6. market cap (USD)': '119645.73519700'},
#  '2019-11-24': {'1a. open (USD)': '7311.10000000',
#   '1b. open (USD)': '7311.10000000',
#   '2a. high (USD)': '7330.39000000',
#   '2b. high (USD)': '7330.39000000',
#   '3a. low (USD)': '6861.00000000',
#   '3b. low (USD)': '6861.00000000',
#   '4a. close (USD)': '6903.28000000',
#   '4b. close (USD)': '6903.28000000',
#   '5. volume': '67890.20648300',
#   '6. market cap (USD)': '67890.20648300'}}

# %%
BTC_openlist = []
BTC_closelist = []
BTC_datelist = []
for date in BTC_dates:
    BTC_datelist.append(date)
    BTC_openlist.append(BTC_dates[date]['1a. open (USD)'])
    BTC_closelist.append(BTC_dates[date]['4a. close (USD)'])

BTC_dict = {'date':BTC_datelist,
    'open':BTC_openlist,
    'close':BTC_closelist}

BTC_dataframe = pd.DataFrame(BTC_dict)
BTC_dataframe
# Out:
#            date            open           close
# 0    2022-08-19  23191.45000000  22925.80000000
# 1    2022-08-18  23342.66000000  23191.20000000
# 2    2022-08-17  23856.15000000  23342.66000000
# 3    2022-08-16  24093.04000000  23854.74000000
# 4    2022-08-15  24305.25000000  24094.82000000
# ..          ...             ...             ...
# 995  2019-11-28   7507.90000000   7419.49000000
# 996  2019-11-27   7154.75000000   7508.52000000
# 997  2019-11-26   7109.99000000   7156.14000000
# 998  2019-11-25   6900.23000000   7109.57000000
# 999  2019-11-24   7311.10000000   6903.28000000
#
# [1000 rows x 3 columns]

# %%
BTC_symbol = 'BTC'
BTC_name = 'Bitcoin'
ETH_symbol = 'ETH'
ETH_name = 'Ethereum'

BTC_dataframe['name'] = BTC_name
BTC_dataframe['symbol'] = BTC_symbol
ETH_dataframe['name'] = ETH_name
ETH_dataframe['symbol'] = ETH_symbol
ETH_dataframe = ETH_dataframe[['date','name','symbol','open','close']]

BTC_dataframe = BTC_dataframe[['date','name','symbol','open','close']]


BTC_dataframe['date'] = pd.to_datetime(BTC_dataframe['date'])
BTC_dataframe['date'] = BTC_dataframe['date'].dt.date
BTC_dataframe = BTC_dataframe.loc[BTC_dataframe['date'] >= datetime.date(2021,7,7)]
BTC_dataframe.sort_values('date', ascending=True, inplace=True)

# %%
ETH_dataframe['date'] = pd.to_datetime(ETH_dataframe['date'])
ETH_dataframe['date'] = ETH_dataframe['date'].dt.date
ETH_dataframe = ETH_dataframe.loc[ETH_dataframe['date'] >= datetime.date(2021,7,7)]
ETH_dataframe.sort_values('date', ascending=True, inplace=True)
ETH_dataframe
# Out:
#            date      name symbol           open          close
# 408  2021-07-07  Ethereum    ETH  2322.51000000  2316.57000000
# 407  2021-07-08  Ethereum    ETH  2316.25000000  2116.33000000
# 406  2021-07-09  Ethereum    ETH  2116.32000000  2146.99000000
# 405  2021-07-10  Ethereum    ETH  2146.99000000  2110.69000000
# 404  2021-07-11  Ethereum    ETH  2110.68000000  2140.45000000
# ..          ...       ...    ...            ...            ...
# 4    2022-08-15  Ethereum    ETH  1935.32000000  1899.06000000
# 3    2022-08-16  Ethereum    ETH  1899.05000000  1876.67000000
# 2    2022-08-17  Ethereum    ETH  1876.67000000  1834.25000000
# 1    2022-08-18  Ethereum    ETH  1834.24000000  1846.39000000
# 0    2022-08-19  Ethereum    ETH  1846.39000000  1819.00000000
#
# [409 rows x 5 columns]

# %%
ETH_dataframe
# Out:
#            date      name symbol           open          close
# 408  2021-07-07  Ethereum    ETH  2322.51000000  2316.57000000
# 407  2021-07-08  Ethereum    ETH  2316.25000000  2116.33000000
# 406  2021-07-09  Ethereum    ETH  2116.32000000  2146.99000000
# 405  2021-07-10  Ethereum    ETH  2146.99000000  2110.69000000
# 404  2021-07-11  Ethereum    ETH  2110.68000000  2140.45000000
# ..          ...       ...    ...            ...            ...
# 4    2022-08-15  Ethereum    ETH  1935.32000000  1899.06000000
# 3    2022-08-16  Ethereum    ETH  1899.05000000  1876.67000000
# 2    2022-08-17  Ethereum    ETH  1876.67000000  1834.25000000
# 1    2022-08-18  Ethereum    ETH  1834.24000000  1846.39000000
# 0    2022-08-19  Ethereum    ETH  1846.39000000  1819.00000000
#
# [409 rows x 5 columns]

# %% [markdown]
# Append Dataframes

# %%
Full_BTC = BTC_df_dates.append(BTC_dataframe)
Full_BTC
# Out:
#            date     name symbol            open           close
# 831  2015-08-08  Bitcoin    BTC         279.742         260.997
# 832  2015-08-09  Bitcoin    BTC         261.116         265.083
# 833  2015-08-10  Bitcoin    BTC         265.478          264.47
# 834  2015-08-11  Bitcoin    BTC         264.342         270.386
# 835  2015-08-12  Bitcoin    BTC         270.598         266.376
# ..          ...      ...    ...             ...             ...
# 4    2022-08-15  Bitcoin    BTC  24305.25000000  24094.82000000
# 3    2022-08-16  Bitcoin    BTC  24093.04000000  23854.74000000
# 2    2022-08-17  Bitcoin    BTC  23856.15000000  23342.66000000
# 1    2022-08-18  Bitcoin    BTC  23342.66000000  23191.20000000
# 0    2022-08-19  Bitcoin    BTC  23191.45000000  22925.80000000
#
# [2569 rows x 5 columns]

# %%
Full_ETH = ETH_df.append(ETH_dataframe)
Full_ETH
# Out:
#           date      name symbol           open          close
# 0   2015-08-08  Ethereum    ETH        2.79376       0.753325
# 1   2015-08-09  Ethereum    ETH       0.706136       0.701897
# 2   2015-08-10  Ethereum    ETH       0.713989       0.708448
# 3   2015-08-11  Ethereum    ETH       0.708087        1.06786
# 4   2015-08-12  Ethereum    ETH        1.05875        1.21744
# ..         ...       ...    ...            ...            ...
# 4   2022-08-15  Ethereum    ETH  1935.32000000  1899.06000000
# 3   2022-08-16  Ethereum    ETH  1899.05000000  1876.67000000
# 2   2022-08-17  Ethereum    ETH  1876.67000000  1834.25000000
# 1   2022-08-18  Ethereum    ETH  1834.24000000  1846.39000000
# 0   2022-08-19  Ethereum    ETH  1846.39000000  1819.00000000
#
# [2569 rows x 5 columns]

# %% [markdown]
# Connect to pgAdmin

# %%
protocol = 'postgresql'
username = 'postgres'
password = f'{pgAdmin_pw}'
host = 'localhost'
port = 5432
database_name = 'crypto_db'
rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
engine = create_engine(rds_connection_string)

# %%
engine.table_names()
# Out:
# ['btc', 'eth']

# %%
Full_ETH.to_sql(name='eth', con=engine, if_exists='append', index=False)

# %%
Full_BTC.to_sql(name='btc', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from eth', con=engine).head()
# Out:
#          date      name symbol      open     close
# 0  2015-08-08  Ethereum    ETH  2.793760  0.753325
# 1  2015-08-09  Ethereum    ETH  0.706136  0.701897
# 2  2015-08-10  Ethereum    ETH  0.713989  0.708448
# 3  2015-08-11  Ethereum    ETH  0.708087  1.067860
# 4  2015-08-12  Ethereum    ETH  1.058750  1.217440

# %%
pd.read_sql_query('select * from btc', con=engine).head()
# Out:
#          date     name symbol        open       close
# 0  2015-08-08  Bitcoin    BTC  279.742004  260.997009
# 1  2015-08-09  Bitcoin    BTC  261.115997  265.083008
# 2  2015-08-10  Bitcoin    BTC  265.477997  264.470001
# 3  2015-08-11  Bitcoin    BTC  264.342010  270.385986
# 4  2015-08-12  Bitcoin    BTC  270.597992  266.376007

# %%
pd.read_sql_query('select * from btc_eth', con=engine).head()
# Out:
#          date    btc_open   btc_close  eth_open  eth_close
# 0  2015-08-08  279.742004  260.997009  2.793760   0.753325
# 1  2015-08-09  261.115997  265.083008  0.706136   0.701897
# 2  2015-08-10  265.477997  264.470001  0.713989   0.708448
# 3  2015-08-11  264.342010  270.385986  0.708087   1.067860
# 4  2015-08-12  270.597992  266.376007  1.058750   1.217440
